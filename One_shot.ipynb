# %%
import csv
import os
import re
import pandas as pd

# %%
def find_all_mention_spans(csv_file, texts_folder, case_insensitive=False):
    results = []
    seen_spans = set() 

    with open(csv_file, newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        mentions_by_doc = {}
        for row in reader:
            doc_id = row['document_id']
            mention = row['mention']
            mentions_by_doc.setdefault(doc_id, []).append(mention)

    for doc_id, mentions in mentions_by_doc.items():
        text_path = os.path.join(texts_folder, f"{doc_id}.txt")
        if not os.path.isfile(text_path):
            print(f"Warning: Text file for document_id {doc_id} not found.")
            continue

        with open(text_path, encoding='utf-8') as f:
            text = f.read()

        for mention in mentions:
            escaped_mention = re.escape(mention)
            flags = re.IGNORECASE if case_insensitive else 0
            matches = list(re.finditer(escaped_mention, text, flags))

            if not matches:
                span_key = (doc_id, mention, -1, -1)
                if span_key not in seen_spans:
                    print(f"Warning: Mention '{mention}' not found in document {doc_id}")
                    results.append({
                        'doc_id': doc_id,
                        'mention': mention,
                        'start': -1,
                        'end': -1
                    })
                    seen_spans.add(span_key)
            else:
                for match in matches:
                    start, end = match.start(), match.end()
                    span_key = (doc_id, mention, start, end)
                    if span_key not in seen_spans:
                        results.append({
                            'doc_id': doc_id,
                            'mention': mention,
                            'start': start,
                            'end': end
                        })
                        seen_spans.add(span_key)

    return results

# %%
csv_file = 'D:/prompting/one_shot/one_pred.csv'
texts_folder = 'D:/prompting/ncbi_texts'
spans = find_all_mention_spans(csv_file, texts_folder, case_insensitive=False)
# Out:
# Warning: Mention 'beta hexosaminidase A deficiency' not found in document 941901
# Warning: Mention 'tumors' not found in document 9420335
# Warning: Mention 'skin fragility' not found in document 9457914
# Warning: Mention 'Cowden disease (CD)' not found in document 9467011
# Warning: Mention 'ovarian cancers' not found in document 9497246
# Warning: Mention 'spinocerebellar ataxias 2' not found in document 9506545
# Warning: Mention 'maternal uniparental disomy (UPD)' not found in document 9674903
# Warning: Mention 'defective thrombosis' not found in document 9689113
# Warning: Mention 'human complement C9 deficiency' not found in document 9703418
# Warning: Mention 'very-long-chain acyl-coenzyme A dehydrogenase (VLCAD) deficiency' not found in document 9709714
# Warning: Mention 'colorectal neoplasia' not found in document 9869602

# %%
spans
# Out:
# [{'doc_id': '932197',
#   'mention': 'hereditary deficiency of the fifth component of complement',
#   'start': 156,
#   'end': 214},
#  {'doc_id': '932197',
#   'mention': 'systemic lupus erythematosus',
#   'start': 279,
#   'end': 307},
#  {'doc_id': '932197', 'mention': 'lupus', 'start': 288, 'end': 293},
#  {'doc_id': '932197', 'mention': 'lupus', 'start': 528, 'end': 533},
#  {'doc_id': '932197', 'mention': 'exacerbations', 'start': 577, 'end': 590},
#  {'doc_id': '932197',
#   'mention': 'underlying disease',
#   'start': 626,
#   'end': 644},
#  {'doc_id': '932197', 'mention': 'C5 deficiency', 'start': 983, 'end': 996},
#  {'doc_id': '932197', 'mention': 'C5D', 'start': 1069, 'end': 1072},
#  {'doc_id': '932197', 'mention': 'C5D', 'start': 1257, 'end': 1260},
#  {'doc_id': '932197', 'mention': 'C5D', 'start': 1426, 'end': 1429},
#  {'doc_id': '932197', 'mention': 'C5D', 'start': 1916, 'end': 1919},
#  {'doc_id': '932197', 'mention': 'C5-deficient', 'start': 1055, 'end': 1067},
#  {'doc_id': '932197', 'mention': 'C5D serum', 'start': 1257, 'end': 1266},
#  {'doc_id': '932197', 'mention': 'C5D serum', 'start': 1426, 'end': 1435},
#  {'doc_id': '932197',
#   'mention': 'membranous glomerulonephritis',
#   'start': 1619,
#   'end': 1648},
#  {'doc_id': '932197', 'mention': 'vasculitis', 'start': 1650, 'end': 1660},
#  {'doc_id': '932197', 'mention': 'arthritis', 'start': 1666, 'end': 1675},
#  {'doc_id': '932197',
#   'mention': 'bacterial infections',
#   'start': 1769,
#   'end': 1789},
#  {'doc_id': '932197',
#   'mention': 'pyogenic infection',
#   'start': 2034,
#   'end': 2052},
#  {'doc_id': '941901',
#   'mention': 'beta hexosaminidase A deficiency',
#   'start': -1,
#   'end': -1},
#  {'doc_id': '941901',
#   'mention': 'deficiency of this enzyme',
#   'start': 73,
#   'end': 98},
#  {'doc_id': '941901', 'mention': 'hex A activity', 'start': 287, 'end': 301},
#  {'doc_id': '941901',
#   'mention': 'deficiency of hex A activity',
#   'start': 273,
#   'end': 301},
#  {'doc_id': '941901',
#   'mention': 'Tay-Sachs disease (TSD)',
#   'start': 347,
#   'end': 370},
#  {'doc_id': '941901', 'mention': 'TSD', 'start': 366, 'end': 369},
#  {'doc_id': '941901', 'mention': 'TSD', 'start': 738, 'end': 741},
#  {'doc_id': '941901', 'mention': 'TSD', 'start': 972, 'end': 975},
#  {'doc_id': '941901', 'mention': 'TSD', 'start': 1114, 'end': 1117},
#  {'doc_id': '941901', 'mention': 'TSD gene', 'start': 738, 'end': 746},
#  {'doc_id': '941901', 'mention': 'mutant TSD gene', 'start': 731, 'end': 746},
#  {'doc_id': '941901',
#   'mention': 'hex A deficiency',
#   'start': 1151,
#   'end': 1167},
#  {'doc_id': '941901',
#   'mention': 'incomplete hex A deficiency',
#   'start': 1140,
#   'end': 1167},
#  {'doc_id': '993342', 'mention': 'C2 deficiency', 'start': 453, 'end': 466},
#  {'doc_id': '993342', 'mention': 'C2 deficiency', 'start': 512, 'end': 525},
#  {'doc_id': '993342', 'mention': 'C2 deficiency', 'start': 603, 'end': 616},
#  {'doc_id': '993342', 'mention': 'C2 deficiency', 'start': 734, 'end': 747},
#  {'doc_id': '993342', 'mention': 'C2 deficiency', 'start': 1337, 'end': 1350},
#  {'doc_id': '993342', 'mention': 'C2 deficiency', 'start': 1448, 'end': 1461},
#  {'doc_id': '993342', 'mention': 'C2 deficiency', 'start': 1489, 'end': 1502},
#  {'doc_id': '993342', 'mention': 'C2 deficiency', 'start': 1666, 'end': 1679},
#  {'doc_id': '993342',
#   'mention': 'connective tissue disorders',
#   'start': 352,
#   'end': 379},
#  {'doc_id': '993342',
#   'mention': 'deficiency of the second component of complement',
#   'start': 105,
#   'end': 153},
#  {'doc_id': '993342',
#   'mention': 'deficiency of the second component of complement',
#   'start': 257,
#   'end': 305},
#  {'doc_id': '9288106',
#   'mention': 'ataxia-telangiectasia',
#   'start': 40,
#   'end': 61},
#  {'doc_id': '9288106', 'mention': 'A-T', 'start': 122, 'end': 125},
#  {'doc_id': '9288106', 'mention': 'A-T', 'start': 304, 'end': 307},
#  {'doc_id': '9288106', 'mention': 'A-T', 'start': 549, 'end': 552},
#  {'doc_id': '9288106', 'mention': 'A-T', 'start': 663, 'end': 666},
#  {'doc_id': '9288106', 'mention': 'A-T', 'start': 1070, 'end': 1073},
#  {'doc_id': '9288106', 'mention': 'cancer', 'start': 235, 'end': 241},
#  {'doc_id': '9288106',
#   'mention': 'lymphoid neoplasias',
#   'start': 254,
#   'end': 273},
#  {'doc_id': '9288106',
#   'mention': 'T-cell prolymphocytic leukaemia',
#   'start': 428,
#   'end': 459},
#  {'doc_id': '9288106', 'mention': 'T-PLL', 'start': 461, 'end': 466},
#  {'doc_id': '9288106', 'mention': 'T-PLL', 'start': 606, 'end': 611},
#  {'doc_id': '9288106', 'mention': 'T-PLL', 'start': 1030, 'end': 1035},
#  {'doc_id': '9288106', 'mention': 'T-PLL', 'start': 1603, 'end': 1608},
#  {'doc_id': '9288106', 'mention': 'T-PLL', 'start': 1741, 'end': 1746},
#  {'doc_id': '9288106', 'mention': 'leukaemia', 'start': 88, 'end': 97},
#  {'doc_id': '9288106', 'mention': 'leukaemia', 'start': 450, 'end': 459},
#  {'doc_id': '9288106', 'mention': 'leukaemia', 'start': 531, 'end': 540},
#  {'doc_id': '9288106', 'mention': 'leukaemia', 'start': 713, 'end': 722},
#  {'doc_id': '9288106', 'mention': 'leukaemia', 'start': 1212, 'end': 1221},
#  {'doc_id': '9288106', 'mention': 'tumour', 'start': 389, 'end': 395},
#  {'doc_id': '9288106', 'mention': 'tumour', 'start': 1160, 'end': 1166},
#  {'doc_id': '9288106', 'mention': 'tumour', 'start': 1279, 'end': 1285},
#  {'doc_id': '9288106', 'mention': 'tumour', 'start': 1517, 'end': 1523},
#  {'doc_id': '9288106', 'mention': 'tumour', 'start': 1641, 'end': 1647},
#  {'doc_id': '9288106',
#   'mention': 'B-cell non-Hodgkins lymphomas',
#   'start': 1309,
#   'end': 1338},
#  {'doc_id': '9288106', 'mention': 'B-NHL', 'start': 1340, 'end': 1345},
#  {'doc_id': '9288106', 'mention': 'B-NHL', 'start': 1353, 'end': 1358},
#  {'doc_id': '9288106',
#   'mention': 'sporadic T-PLL',
#   'start': 1594,
#   'end': 1608},
#  {'doc_id': '9288106',
#   'mention': 'hereditary predisposition to T-PLL',
#   'start': 1712,
#   'end': 1746},
#  {'doc_id': '9294109', 'mention': 'Myotonic dystrophy', 'start': 0, 'end': 18},
#  {'doc_id': '9294109',
#   'mention': 'Myotonic dystrophy',
#   'start': 114,
#   'end': 132},
#  {'doc_id': '9294109', 'mention': 'DM', 'start': 134, 'end': 136},
#  {'doc_id': '9294109', 'mention': 'DM', 'start': 262, 'end': 264},
#  {'doc_id': '9294109', 'mention': 'DM', 'start': 281, 'end': 283},
#  {'doc_id': '9294109', 'mention': 'DM', 'start': 398, 'end': 400},
#  {'doc_id': '9294109', 'mention': 'DM', 'start': 631, 'end': 633},
#  {'doc_id': '9294109', 'mention': 'DM', 'start': 681, 'end': 683},
#  {'doc_id': '9294109', 'mention': 'DM', 'start': 1228, 'end': 1230},
#  {'doc_id': '9294109', 'mention': 'DM', 'start': 1279, 'end': 1281},
#  {'doc_id': '9294109',
#   'mention': 'muscular disorder',
#   'start': 158,
#   'end': 175},
#  {'doc_id': '9311732', 'mention': 'retinoblastoma', 'start': 71, 'end': 85},
#  {'doc_id': '9311732', 'mention': 'retinoblastoma', 'start': 129, 'end': 143},
#  {'doc_id': '9311732', 'mention': 'retinoblastoma', 'start': 278, 'end': 292},
#  {'doc_id': '9311732', 'mention': 'retinoblastoma', 'start': 440, 'end': 454},
#  {'doc_id': '9311732',
#   'mention': 'retinoblastoma',
#   'start': 1839,
#   'end': 1853},
#  {'doc_id': '9311732',
#   'mention': 'retinoblastoma',
#   'start': 1939,
#   'end': 1953},
#  {'doc_id': '9311732', 'mention': 'tumors', 'start': 533, 'end': 539},
#  {'doc_id': '9311732', 'mention': 'tumors', 'start': 742, 'end': 748},
#  {'doc_id': '9311732', 'mention': 'tumors', 'start': 894, 'end': 900},
#  {'doc_id': '9311732', 'mention': 'tumors', 'start': 928, 'end': 934},
#  {'doc_id': '9311732', 'mention': 'tumors', 'start': 997, 'end': 1003},
#  {'doc_id': '9311732', 'mention': 'tumors', 'start': 1093, 'end': 1099},
#  {'doc_id': '9311732', 'mention': 'tumors', 'start': 1233, 'end': 1239},
#  {'doc_id': '9311732', 'mention': 'tumors', 'start': 1792, 'end': 1798},
#  {'doc_id': '9336417',
#   'mention': 'ankylosing spondylitis',
#   'start': 18,
#   'end': 40},
#  {'doc_id': '9336417',
#   'mention': 'ankylosing spondylitis',
#   'start': 199,
#   'end': 221},
#  {'doc_id': '9336417',
#   'mention': 'ankylosing spondylitis (AS)',
#   'start': 199,
#   'end': 226},
#  {'doc_id': '9336417', 'mention': 'AS', 'start': 223, 'end': 225},
#  {'doc_id': '9336417', 'mention': 'AS', 'start': 248, 'end': 250},
#  {'doc_id': '9336417', 'mention': 'AS', 'start': 808, 'end': 810},
#  {'doc_id': '9336417', 'mention': 'AS', 'start': 1512, 'end': 1514},
#  {'doc_id': '9336417', 'mention': 'AS', 'start': 1693, 'end': 1695},
#  {'doc_id': '9336417', 'mention': 'disease', 'start': 415, 'end': 422},
#  {'doc_id': '9336417', 'mention': 'disease', 'start': 863, 'end': 870},
#  {'doc_id': '9336417', 'mention': 'disease', 'start': 1055, 'end': 1062},
#  {'doc_id': '9336417', 'mention': 'disease', 'start': 1084, 'end': 1091},
#  {'doc_id': '9336417', 'mention': 'disease', 'start': 1131, 'end': 1138},
#  {'doc_id': '9336417', 'mention': 'disease', 'start': 1235, 'end': 1242},
#  {'doc_id': '9336417', 'mention': 'disease', 'start': 1272, 'end': 1279},
#  {'doc_id': '9336417', 'mention': 'disease', 'start': 1588, 'end': 1595},
#  {'doc_id': '9336417',
#   'mention': 'disease severity',
#   'start': 415,
#   'end': 431},
#  {'doc_id': '9336417',
#   'mention': 'disease severity',
#   'start': 1084,
#   'end': 1100},
#  {'doc_id': '9342365',
#   'mention': 'breast and ovarian cancer',
#   'start': 163,
#   'end': 188},
#  {'doc_id': '9342365', 'mention': 'tumor', 'start': 241, 'end': 246},
#  {'doc_id': '9342365', 'mention': 'tumor', 'start': 1403, 'end': 1408},
#  {'doc_id': '9358014',
#   'mention': 'hereditary hemochromatosis (HH)',
#   'start': 95,
#   'end': 126},
#  {'doc_id': '9358014', 'mention': 'HH', 'start': 123, 'end': 125},
#  {'doc_id': '9358014', 'mention': 'HH', 'start': 798, 'end': 800},
#  {'doc_id': '9358014', 'mention': 'HH', 'start': 945, 'end': 947},
#  {'doc_id': '9358014', 'mention': 'cancer', 'start': 1048, 'end': 1054},
#  {'doc_id': '9360520',
#   'mention': 'Autosomal dominant neurohypophyseal diabetes insipidus',
#   'start': 0,
#   'end': 54},
#  {'doc_id': '9360520',
#   'mention': 'Autosomal dominant neurohypophyseal diabetes insipidus',
#   'start': 131,
#   'end': 185},
#  {'doc_id': '9360520',
#   'mention': 'neurohypophyseal diabetes insipidus',
#   'start': 19,
#   'end': 54},
#  {'doc_id': '9360520',
#   'mention': 'neurohypophyseal diabetes insipidus',
#   'start': 150,
#   'end': 185},
#  {'doc_id': '9360520', 'mention': 'ADNDI', 'start': 187, 'end': 192},
#  {'doc_id': '9360520', 'mention': 'ADNDI', 'start': 587, 'end': 592},
#  {'doc_id': '9360520',
#   'mention': 'diabetes insipidus',
#   'start': 36,
#   'end': 54},
#  {'doc_id': '9360520',
#   'mention': 'diabetes insipidus',
#   'start': 167,
#   'end': 185},
#  {'doc_id': '9360520',
#   'mention': 'diabetes insipidus',
#   'start': 453,
#   'end': 471},
#  {'doc_id': '9371490', 'mention': 'prostate cancer', 'start': 47, 'end': 62},
#  {'doc_id': '9371490', 'mention': 'prostate cancer', 'start': 387, 'end': 402},
#  {'doc_id': '9371490', 'mention': 'prostate cancer', 'start': 667, 'end': 682},
#  {'doc_id': '9371490',
#   'mention': 'prostate cancer',
#   'start': 1149,
#   'end': 1164},
#  {'doc_id': '9371490',
#   'mention': 'prostate carcinoma',
#   'start': 73,
#   'end': 91},
#  {'doc_id': '9371490', 'mention': 'cancer', 'start': 56, 'end': 62},
#  {'doc_id': '9371490', 'mention': 'cancer', 'start': 116, 'end': 122},
#  {'doc_id': '9371490', 'mention': 'cancer', 'start': 230, 'end': 236},
#  {'doc_id': '9371490', 'mention': 'cancer', 'start': 396, 'end': 402},
#  {'doc_id': '9371490', 'mention': 'cancer', 'start': 676, 'end': 682},
#  {'doc_id': '9371490', 'mention': 'cancer', 'start': 1158, 'end': 1164},
#  {'doc_id': '9371490', 'mention': 'tumor', 'start': 526, 'end': 531},
#  {'doc_id': '9371490', 'mention': 'tumor', 'start': 719, 'end': 724},
#  {'doc_id': '9371490', 'mention': 'tumor', 'start': 1065, 'end': 1070},
#  {'doc_id': '9371490', 'mention': 'prostate tumors', 'start': 710, 'end': 725},
#  {'doc_id': '9371490', 'mention': 'tumors', 'start': 719, 'end': 725},
#  {'doc_id': '9371490', 'mention': 'tumors', 'start': 1065, 'end': 1071},
#  {'doc_id': '9382108',
#   'mention': 'Huntington disease',
#   'start': 41,
#   'end': 59},
#  {'doc_id': '9382108',
#   'mention': 'Huntington disease',
#   'start': 94,
#   'end': 112},
#  {'doc_id': '9382108', 'mention': 'HD', 'start': 114, 'end': 116},
#  {'doc_id': '9382108', 'mention': 'HD', 'start': 232, 'end': 234},
#  {'doc_id': '9382108', 'mention': 'HD', 'start': 426, 'end': 428},
#  {'doc_id': '9385378',
#   'mention': 'mucopolysaccharidosis IVA',
#   'start': 96,
#   'end': 121},
#  {'doc_id': '9385378', 'mention': 'MPS IVA', 'start': 150, 'end': 157},
#  {'doc_id': '9385378', 'mention': 'MPS IVA', 'start': 498, 'end': 505},
#  {'doc_id': '9385378', 'mention': 'MPS IVA', 'start': 772, 'end': 779},
#  {'doc_id': '9385378',
#   'mention': 'lysosomal storage disorder',
#   'start': 185,
#   'end': 211},
#  {'doc_id': '9391879',
#   'mention': 'BRCA1 germline mutations',
#   'start': 17,
#   'end': 41},
#  {'doc_id': '9391879',
#   'mention': 'breast/ovarian cancer',
#   'start': 55,
#   'end': 76},
#  {'doc_id': '9391879',
#   'mention': 'breast/ovarian cancer',
#   'start': 127,
#   'end': 148},
#  {'doc_id': '9391879',
#   'mention': 'breast/ovarian cancer',
#   'start': 835,
#   'end': 856},
#  {'doc_id': '9391879',
#   'mention': 'germline mutations',
#   'start': 23,
#   'end': 41},
#  {'doc_id': '9391879',
#   'mention': 'germline mutations',
#   'start': 162,
#   'end': 180},
#  {'doc_id': '9391879',
#   'mention': 'germline mutations',
#   'start': 219,
#   'end': 237},
#  {'doc_id': '9391879', 'mention': 'breast cancer', 'start': 247, 'end': 260},
#  {'doc_id': '9391879',
#   'mention': 'breast-ovarian cancer',
#   'start': 281,
#   'end': 302},
#  {'doc_id': '9391879', 'mention': 'disease', 'start': 534, 'end': 541},
#  {'doc_id': '9391879', 'mention': 'disease', 'start': 573, 'end': 580},
#  {'doc_id': '9391889',
#   'mention': 'congenital myotonic dystrophy',
#   'start': 25,
#   'end': 54},
#  {'doc_id': '9391889',
#   'mention': 'congenital myotonic dystrophy',
#   'start': 104,
#   'end': 133},
#  {'doc_id': '9391889', 'mention': 'DM', 'start': 135, 'end': 137},
#  {'doc_id': '9391889', 'mention': 'DM', 'start': 337, 'end': 339},
#  {'doc_id': '9391889', 'mention': 'DM', 'start': 381, 'end': 383},
#  {'doc_id': '9391889', 'mention': 'DM', 'start': 473, 'end': 475},
#  {'doc_id': '9391889', 'mention': 'DM', 'start': 569, 'end': 571},
#  {'doc_id': '9391889', 'mention': 'DM', 'start': 619, 'end': 621},
#  {'doc_id': '9391889', 'mention': 'DM', 'start': 757, 'end': 759},
#  {'doc_id': '9391889', 'mention': 'DM', 'start': 957, 'end': 959},
#  {'doc_id': '9391889', 'mention': 'DM', 'start': 1014, 'end': 1016},
#  {'doc_id': '9391889', 'mention': 'DM', 'start': 1065, 'end': 1067},
#  {'doc_id': '9391889',
#   'mention': 'muscular weakness',
#   'start': 212,
#   'end': 229},
#  {'doc_id': '9391889',
#   'mention': 'childhood onset DM',
#   'start': 321,
#   'end': 339},
#  {'doc_id': '9391889',
#   'mention': 'adult type of DM',
#   'start': 367,
#   'end': 383},
#  {'doc_id': '9391889',
#   'mention': 'paternal transmission of congenital DM',
#   'start': 437,
#   'end': 475},
#  {'doc_id': '9391889',
#   'mention': 'paternal transmission of congenital DM',
#   'start': 721,
#   'end': 759},
#  {'doc_id': '9391889',
#   'mention': 'paternal transmission of congenital DM',
#   'start': 978,
#   'end': 1016},
#  {'doc_id': '9391889', 'mention': 'congenital DM', 'start': 462, 'end': 475},
#  {'doc_id': '9391889', 'mention': 'congenital DM', 'start': 558, 'end': 571},
#  {'doc_id': '9391889', 'mention': 'congenital DM', 'start': 746, 'end': 759},
#  {'doc_id': '9391889', 'mention': 'congenital DM', 'start': 946, 'end': 959},
#  {'doc_id': '9391889', 'mention': 'congenital DM', 'start': 1003, 'end': 1016},
#  {'doc_id': '9391889', 'mention': 'adult onset DM', 'start': 607, 'end': 621},
#  {'doc_id': '9400934', 'mention': 'retinoblastoma', 'start': 59, 'end': 73},
#  {'doc_id': '9400934', 'mention': 'retinoblastoma', 'start': 151, 'end': 165},
#  {'doc_id': '9400934', 'mention': 'retinoblastoma', 'start': 753, 'end': 767},
#  {'doc_id': '9400934', 'mention': 'retinal tumours', 'start': 210, 'end': 225},
#  {'doc_id': '9400934', 'mention': 'pineal tumours', 'start': 366, 'end': 380},
#  {'doc_id': '9420335', 'mention': 'tumor', 'start': 4, 'end': 9},
#  {'doc_id': '9420335', 'mention': 'tumor', 'start': 150, 'end': 155},
#  {'doc_id': '9420335',
#   'mention': 'pancreatic cancers',
#   'start': 254,
#   'end': 272},
#  {'doc_id': '9420335', 'mention': 'tumors', 'start': -1, 'end': -1},
#  {'doc_id': '9425228', 'mention': 'melanoma', 'start': 52, 'end': 60},
#  {'doc_id': '9425228', 'mention': 'melanoma', 'start': 208, 'end': 216},
#  {'doc_id': '9425228', 'mention': 'melanoma', 'start': 321, 'end': 329},
#  {'doc_id': '9425228', 'mention': 'melanoma', 'start': 958, 'end': 966},
#  {'doc_id': '9425228', 'mention': 'melanoma', 'start': 1010, 'end': 1018},
#  {'doc_id': '9425228',
#   'mention': 'melanoma-predisposing gene',
#   'start': 1010,
#   'end': 1036},
#  {'doc_id': '9425239',
#   'mention': 'myotonic dystrophy',
#   'start': 77,
#   'end': 95},
#  {'doc_id': '9425239',
#   'mention': 'myotonic dystrophy',
#   'start': 127,
#   'end': 145},
#  {'doc_id': '9425239',
#   'mention': 'myotonic dystrophy',
#   'start': 1053,
#   'end': 1071},
#  {'doc_id': '9425239',
#   'mention': 'myotonic dystrophy (DM)',
#   'start': 127,
#   'end': 150},
#  {'doc_id': '9425239', 'mention': 'DM', 'start': 147, 'end': 149},
#  {'doc_id': '9425239', 'mention': 'DM', 'start': 215, 'end': 217},
#  {'doc_id': '9425239', 'mention': 'DM', 'start': 293, 'end': 295},
#  {'doc_id': '9425239', 'mention': 'DM', 'start': 963, 'end': 965},
#  {'doc_id': '9425239', 'mention': 'disease', 'start': 644, 'end': 651},
#  {'doc_id': '9425239', 'mention': 'symptoms', 'start': 760, 'end': 768},
#  {'doc_id': '9427148',
#   'mention': 'Aspartylglucosaminuria',
#   'start': 0,
#   'end': 22},
#  {'doc_id': '9427148',
#   'mention': 'Aspartylglucosaminuria',
#   'start': 48,
#   'end': 70},
#  {'doc_id': '9427148',
#   'mention': 'Aspartylglucosaminuria (AGU)',
#   'start': 48,
#   'end': 76},
#  {'doc_id': '9427148', 'mention': 'AGU', 'start': 72, 'end': 75},
#  {'doc_id': '9427148', 'mention': 'AGU', 'start': 203, 'end': 206},
#  {'doc_id': '9427148', 'mention': 'AGU', 'start': 354, 'end': 357},
#  {'doc_id': '9427148', 'mention': 'AGU', 'start': 559, 'end': 562},
#  {'doc_id': '9427148', 'mention': 'disorder', 'start': 87, 'end': 95},
#  {'doc_id': '9427148', 'mention': 'disorder', 'start': 419, 'end': 427},
#  {'doc_id': '9427148', 'mention': 'disease', 'start': 624, 'end': 631},
#  {'doc_id': '9439660',
#   'mention': 'ataxia-telangiectasia',
#   'start': 42,
#   'end': 63},
#  {'doc_id': '9439660',
#   'mention': 'ataxia-telangiectasia',
#   'start': 152,
#   'end': 173},
#  {'doc_id': '9439660',
#   'mention': 'ataxia-telangiectasia (A-T)',
#   'start': 152,
#   'end': 179},
#  {'doc_id': '9439660', 'mention': 'A-T', 'start': 175, 'end': 178},
#  {'doc_id': '9439660', 'mention': 'A-T', 'start': 455, 'end': 458},
#  {'doc_id': '9439660', 'mention': 'A-T', 'start': 621, 'end': 624},
#  {'doc_id': '9439660', 'mention': 'A-T', 'start': 647, 'end': 650},
#  {'doc_id': '9439660', 'mention': 'A-T', 'start': 840, 'end': 843},
#  {'doc_id': '9439660', 'mention': 'A-T', 'start': 1092, 'end': 1095},
#  {'doc_id': '9439660',
#   'mention': 'autosomal recessive syndrome',
#   'start': 236,
#   'end': 264},
#  {'doc_id': '9439660', 'mention': 'radiosensitivity', 'start': 99, 'end': 115},
#  {'doc_id': '9439660',
#   'mention': 'radiosensitivity',
#   'start': 332,
#   'end': 348},
#  {'doc_id': '9439660',
#   'mention': 'radiosensitivity',
#   'start': 520,
#   'end': 536},
#  {'doc_id': '9439660',
#   'mention': 'radiosensitivity',
#   'start': 1036,
#   'end': 1052},
#  {'doc_id': '9439660', 'mention': 'malignancy', 'start': 381, 'end': 391},
#  {'doc_id': '9439660', 'mention': 'cancer', 'start': 470, 'end': 476},
#  {'doc_id': '9439660', 'mention': 'cancer', 'start': 1221, 'end': 1227},
#  {'doc_id': '9439660', 'mention': 'ATM carriers', 'start': 821, 'end': 833},
#  {'doc_id': '9439660', 'mention': 'cancers', 'start': 1221, 'end': 1228},
#  {'doc_id': '9439660', 'mention': 'tumor', 'start': 1301, 'end': 1306},
#  {'doc_id': '9443866',
#   'mention': 'Ataxia-telangiectasia',
#   'start': 0,
#   'end': 21},
#  {'doc_id': '9443866',
#   'mention': 'ATM heterozygotes',
#   'start': 151,
#   'end': 168},
#  {'doc_id': '9443866', 'mention': 'diseases', 'start': 197, 'end': 205},
#  {'doc_id': '9443866', 'mention': 'breast cancer', 'start': 215, 'end': 228},
#  {'doc_id': '9443866',
#   'mention': 'ataxia-telangiectasia (A-T)',
#   'start': 309,
#   'end': 336},
#  {'doc_id': '9443866',
#   'mention': 'A-T heterozygotes',
#   'start': 1236,
#   'end': 1253},
#  {'doc_id': '9448273',
#   'mention': 'von Hippel-Lindau tumor suppressor gene',
#   'start': 4,
#   'end': 43},
#  {'doc_id': '9448273',
#   'mention': 'von Hippel-Lindau (VHL) tumor suppressor gene',
#   'start': 123,
#   'end': 168},
#  {'doc_id': '9448273',
#   'mention': 'VHL cancer syndrome',
#   'start': 215,
#   'end': 234},
#  {'doc_id': '9448273',
#   'mention': 'renal cell carcinomas (RCC)',
#   'start': 267,
#   'end': 294},
#  {'doc_id': '9448273',
#   'mention': 'brain hemangioblastomas',
#   'start': 299,
#   'end': 322},
#  {'doc_id': '9448273',
#   'mention': 'VHL-negative 786-0 RCC cells',
#   'start': 324,
#   'end': 352},
#  {'doc_id': '9448273', 'mention': 'cancer cells', 'start': 571, 'end': 583},
#  {'doc_id': '9448273', 'mention': 'cancer cells', 'start': 742, 'end': 754},
#  {'doc_id': '9448273',
#   'mention': 'RCC cancer cells',
#   'start': 738,
#   'end': 754},
#  {'doc_id': '9448273', 'mention': 'tumor', 'start': 22, 'end': 27},
#  {'doc_id': '9448273', 'mention': 'tumor', 'start': 147, 'end': 152},
#  {'doc_id': '9448273', 'mention': 'tumor', 'start': 357, 'end': 362},
#  {'doc_id': '9448273', 'mention': 'tumor', 'start': 1200, 'end': 1205},
#  {'doc_id': '9448273', 'mention': 'tumor', 'start': 1304, 'end': 1309},
#  {'doc_id': '9448273', 'mention': 'tumor suppressor', 'start': 22, 'end': 38},
#  {'doc_id': '9448273',
#   'mention': 'tumor suppressor',
#   'start': 147,
#   'end': 163},
#  {'doc_id': '9448273',
#   'mention': 'tumor suppressor',
#   'start': 1304,
#   'end': 1320},
#  {'doc_id': '9450866', 'mention': 'Piebaldism', 'start': 0, 'end': 10},
#  {'doc_id': '9450866', 'mention': 'deafness', 'start': 16, 'end': 24},
#  {'doc_id': '9450866', 'mention': 'deafness', 'start': 171, 'end': 179},
#  {'doc_id': '9450866', 'mention': 'deafness', 'start': 431, 'end': 439},
#  {'doc_id': '9450866', 'mention': 'deafness', 'start': 514, 'end': 522},
#  {'doc_id': '9450866', 'mention': 'piebaldism', 'start': 122, 'end': 132},
#  {'doc_id': '9450866', 'mention': 'piebaldism', 'start': 464, 'end': 474},
#  {'doc_id': '9450866', 'mention': 'piebaldism', 'start': 584, 'end': 594},
#  {'doc_id': '9450866', 'mention': 'piebaldism', 'start': 675, 'end': 685},
#  {'doc_id': '9450866',
#   'mention': 'congenital sensorineural deafness',
#   'start': 146,
#   'end': 179},
#  {'doc_id': '9450866',
#   'mention': 'sensorineural deafness',
#   'start': 157,
#   'end': 179},
#  {'doc_id': '9450866',
#   'mention': 'sensorineural deafness',
#   'start': 500,
#   'end': 522},
#  {'doc_id': '9450866',
#   'mention': 'Waardenburg syndrome',
#   'start': 711,
#   'end': 731},
#  {'doc_id': '9457913',
#   'mention': 'generalized atrophic benign epidermolysis bullosa',
#   'start': 142,
#   'end': 191},
#  {'doc_id': '9457913',
#   'mention': 'generalized atrophic benign epidermolysis bullosa',
#   'start': 207,
#   'end': 256},
#  {'doc_id': '9457913',
#   'mention': 'generalized atrophic benign epidermolysis bullosa',
#   'start': 451,
#   'end': 500},
#  {'doc_id': '9457914',
#   'mention': 'generalized atrophic benign epidermolysis bullosa',
#   'start': 62,
#   'end': 111},
#  {'doc_id': '9457914',
#   'mention': 'generalized atrophic benign epidermolysis bullosa',
#   'start': 173,
#   'end': 222},
#  {'doc_id': '9457914',
#   'mention': 'generalized atrophic benign epidermolysis bullosa',
#   'start': 524,
#   'end': 573},
#  {'doc_id': '9457914',
#   'mention': 'junctional epidermolysis bullosa',
#   'start': 252,
#   'end': 284},
#  {'doc_id': '9457914',
#   'mention': 'generalized blistering',
#   'start': 291,
#   'end': 313},
#  {'doc_id': '9457914', 'mention': 'nail dystrophy', 'start': 315, 'end': 329},
#  {'doc_id': '9457914', 'mention': 'patchy alopecia', 'start': 331, 'end': 346},
#  {'doc_id': '9457914',
#   'mention': 'dental abnormalities',
#   'start': 352,
#   'end': 372},
#  {'doc_id': '9457914', 'mention': 'skin fragility', 'start': -1, 'end': -1},
#  {'doc_id': '9463309', 'mention': 'anhaptoglobinemia', 'start': 46, 'end': 63},
#  {'doc_id': '9463309',
#   'mention': 'anhaptoglobinemia',
#   'start': 152,
#   'end': 169},
#  {'doc_id': '9463309',
#   'mention': 'anhaptoglobinemia',
#   'start': 456,
#   'end': 473},
#  {'doc_id': '9463309',
#   'mention': 'anhaptoglobinemia',
#   'start': 1746,
#   'end': 1763},
#  {'doc_id': '9463309',
#   'mention': 'hypohaptoglobinemia',
#   'start': 678,
#   'end': 697},
#  {'doc_id': '9463309',
#   'mention': 'hypohaptoglobinemia',
#   'start': 1871,
#   'end': 1890},
#  {'doc_id': '9463309',
#   'mention': 'hypohaptoglobinemic',
#   'start': 879,
#   'end': 898},
#  {'doc_id': '9463309',
#   'mention': 'hypohaptoglobinemic',
#   'start': 986,
#   'end': 1005},
#  {'doc_id': '9463309',
#   'mention': 'anomalous inheritance of Hp phenotypes',
#   'start': 1083,
#   'end': 1121},
#  {'doc_id': '9463309',
#   'mention': 'anomalous inheritance of Hp phenotypes',
#   'start': 1785,
#   'end': 1823},
#  {'doc_id': '9463314', 'mention': 'ATM mutations', 'start': 0, 'end': 13},
#  {'doc_id': '9463314', 'mention': 'ATM mutations', 'start': 194, 'end': 207},
#  {'doc_id': '9463314', 'mention': 'ATM mutations', 'start': 285, 'end': 298},
#  {'doc_id': '9463314',
#   'mention': 'ataxia-telangiectasia',
#   'start': 32,
#   'end': 53},
#  {'doc_id': '9463314',
#   'mention': 'ataxia-telangiectasia',
#   'start': 220,
#   'end': 241},
#  {'doc_id': '9463314',
#   'mention': 'ataxia-telangiectasia (A-T)',
#   'start': 220,
#   'end': 247},
#  {'doc_id': '9463314', 'mention': 'breast cancer', 'start': 150, 'end': 163},
#  {'doc_id': '9463314', 'mention': 'breast cancer', 'start': 613, 'end': 626},
#  {'doc_id': '9463314',
#   'mention': 'cerebellar degeneration',
#   'start': 455,
#   'end': 478},
#  {'doc_id': '9463314',
#   'mention': 'cerebellar degeneration',
#   'start': 771,
#   'end': 794},
#  {'doc_id': '9463314', 'mention': 'A-T', 'start': 243, 'end': 246},
#  {'doc_id': '9463314', 'mention': 'A-T', 'start': 520, 'end': 523},
#  {'doc_id': '9463314', 'mention': 'A-T', 'start': 731, 'end': 734},
#  {'doc_id': '9463314', 'mention': 'A-T', 'start': 965, 'end': 968},
#  {'doc_id': '9463314', 'mention': 'A-T', 'start': 1254, 'end': 1257},
#  {'doc_id': '9463314', 'mention': 'leukemia', 'start': 126, 'end': 134},
#  {'doc_id': '9463314', 'mention': 'leukemia', 'start': 1009, 'end': 1017},
#  {'doc_id': '9463314', 'mention': 'lymphoma', 'start': 136, 'end': 144},
#  {'doc_id': '9463314', 'mention': 'lymphoma', 'start': 1019, 'end': 1027},
#  {'doc_id': '9463314', 'mention': 'lymphoma', 'start': 1074, 'end': 1082},
#  {'doc_id': '9463314',
#   'mention': 'preleukemic T-cell proliferation',
#   'start': 1029,
#   'end': 1061},
#  {'doc_id': '9463314',
#   'mention': 'Hodgkin lymphoma',
#   'start': 1066,
#   'end': 1082},
#  {'doc_id': '9463314', 'mention': 'ATM mutation', 'start': 0, 'end': 12},
#  {'doc_id': '9463314', 'mention': 'ATM mutation', 'start': 194, 'end': 206},
#  {'doc_id': '9463314', 'mention': 'ATM mutation', 'start': 285, 'end': 297},
#  {'doc_id': '9463314', 'mention': 'ATM mutation', 'start': 537, 'end': 549},
#  {'doc_id': '9463314', 'mention': 'ATM mutation', 'start': 1123, 'end': 1135},
#  {'doc_id': '9463314',
#   'mention': 'missense mutations',
#   'start': 1153,
#   'end': 1171},
#  {'doc_id': '9463314',
#   'mention': 'missense mutations',
#   'start': 1297,
#   'end': 1315},
#  {'doc_id': '9463314',
#   'mention': 'in-frame deletions',
#   'start': 1176,
#   'end': 1194},
#  {'doc_id': '9463314',
#   'mention': 'in-frame deletions',
#   'start': 1275,
#   'end': 1293},
#  {'doc_id': '9463318',
#   'mention': 'myotonic dystrophy',
#   'start': 35,
#   'end': 53},
#  {'doc_id': '9463318',
#   'mention': 'myotonic dystrophy',
#   'start': 318,
#   'end': 336},
#  {'doc_id': '9463318', 'mention': 'congenital', 'start': 975, 'end': 985},
#  {'doc_id': '9465039', 'mention': 'hemochromatosis', 'start': 4, 'end': 19},
#  {'doc_id': '9465039', 'mention': 'hemochromatosis', 'start': 196, 'end': 211},
#  {'doc_id': '9465039',
#   'mention': 'hemochromatosis',
#   'start': 1995,
#   'end': 2010},
#  {'doc_id': '9465039',
#   'mention': 'hereditary hemochromatosis',
#   'start': 185,
#   'end': 211},
#  {'doc_id': '9465039',
#   'mention': 'hereditary hemochromatosis',
#   'start': 1984,
#   'end': 2010},
#  {'doc_id': '9465301',
#   'mention': 'Angelman syndrome',
#   'start': 173,
#   'end': 190},
#  {'doc_id': '9467011', 'mention': 'Cowden disease', 'start': 53, 'end': 67},
#  {'doc_id': '9467011', 'mention': 'Cowden disease', 'start': 674, 'end': 688},
#  {'doc_id': '9467011',
#   'mention': 'Bannayan-Zonana syndrome',
#   'start': 72,
#   'end': 96},
#  {'doc_id': '9467011', 'mention': 'breast', 'start': 429, 'end': 435},
#  {'doc_id': '9467011', 'mention': 'breast', 'start': 2126, 'end': 2132},
#  {'doc_id': '9467011', 'mention': 'breast', 'start': 2233, 'end': 2239},
#  {'doc_id': '9467011', 'mention': 'breast', 'start': 2416, 'end': 2422},
#  {'doc_id': '9467011', 'mention': 'breast', 'start': 2697, 'end': 2703},
#  {'doc_id': '9467011', 'mention': 'brain', 'start': 437, 'end': 442},
#  {'doc_id': '9467011', 'mention': 'prostate', 'start': 444, 'end': 452},
#  {'doc_id': '9467011', 'mention': 'kidney cancer', 'start': 457, 'end': 470},
#  {'doc_id': '9467011',
#   'mention': 'endometrial carcinomas',
#   'start': 521,
#   'end': 543},
#  {'doc_id': '9467011',
#   'mention': 'malignant melanoma',
#   'start': 545,
#   'end': 563},
#  {'doc_id': '9467011', 'mention': 'thyroid tumours', 'start': 568, 'end': 583},
#  {'doc_id': '9467011',
#   'mention': 'hamartoma syndromes',
#   'start': 102,
#   'end': 121},
#  {'doc_id': '9467011',
#   'mention': 'hamartoma syndromes',
#   'start': 653,
#   'end': 672},
#  {'doc_id': '9467011',
#   'mention': 'Cowden disease (CD)',
#   'start': -1,
#   'end': -1},
#  {'doc_id': '9467011',
#   'mention': 'Bannayan-Zonana (BZS)',
#   'start': 710,
#   'end': 731},
#  {'doc_id': '9467011',
#   'mention': 'malignant breast disease',
#   'start': 2406,
#   'end': 2430},
#  {'doc_id': '9467011',
#   'mention': 'central nervous system',
#   'start': 2664,
#   'end': 2686},
#  {'doc_id': '9467011', 'mention': 'thyroid', 'start': 568, 'end': 575},
#  {'doc_id': '9467011', 'mention': 'thyroid', 'start': 2688, 'end': 2695},
#  {'doc_id': '9467011', 'mention': 'skin', 'start': 2705, 'end': 2709},
#  {'doc_id': '9467011',
#   'mention': 'gastrointestinal tract',
#   'start': 2714,
#   'end': 2736},
#  {'doc_id': '9472666',
#   'mention': 'complement component C6 deficiency',
#   'start': 35,
#   'end': 69},
#  {'doc_id': '9472666', 'mention': 'C6D', 'start': 137, 'end': 140},
#  {'doc_id': '9472666', 'mention': 'C6D', 'start': 272, 'end': 275},
#  {'doc_id': '9472666', 'mention': 'C6D', 'start': 720, 'end': 723},
#  {'doc_id': '9472666',
#   'mention': 'meningococcal meningitis',
#   'start': 200,
#   'end': 224},
#  {'doc_id': '9472666', 'mention': 'meningitis', 'start': 214, 'end': 224},
#  {'doc_id': '9472666', 'mention': 'meningitis', 'start': 300, 'end': 310},
#  {'doc_id': '9472666',
#   'mention': 'neisserial infection',
#   'start': 320,
#   'end': 340},
#  {'doc_id': '9482572', 'mention': 'aniridia', 'start': 69, 'end': 77},
#  {'doc_id': '9482572', 'mention': 'aniridia', 'start': 295, 'end': 303},
#  {'doc_id': '9482572', 'mention': 'Peters anomaly', 'start': 120, 'end': 134},
#  {'doc_id': '9482572',
#   'mention': 'congenital cataracts',
#   'start': 141,
#   'end': 161},
#  {'doc_id': '9482572',
#   'mention': 'autosomal dominant keratitis',
#   'start': 168,
#   'end': 196},
#  {'doc_id': '9482572',
#   'mention': 'isolated foveal hypoplasia',
#   'start': 207,
#   'end': 233},
#  {'doc_id': '9497246', 'mention': 'breast cancer', 'start': 78, 'end': 91},
#  {'doc_id': '9497246', 'mention': 'breast cancer', 'start': 189, 'end': 202},
#  {'doc_id': '9497246', 'mention': 'breast cancer', 'start': 299, 'end': 312},
#  {'doc_id': '9497246', 'mention': 'breast cancer', 'start': 826, 'end': 839},
#  {'doc_id': '9497246', 'mention': 'breast cancer', 'start': 981, 'end': 994},
#  {'doc_id': '9497246', 'mention': 'breast cancer', 'start': 1616, 'end': 1629},
#  {'doc_id': '9497246', 'mention': 'breast cancer', 'start': 1863, 'end': 1876},
#  {'doc_id': '9497246', 'mention': 'ovarian cancers', 'start': -1, 'end': -1},
#  {'doc_id': '9497246',
#   'mention': 'breast-ovarian cancer',
#   'start': 681,
#   'end': 702},
#  {'doc_id': '9497246',
#   'mention': 'female breast cancer',
#   'start': 819,
#   'end': 839},
#  {'doc_id': '9497246',
#   'mention': 'female breast cancer',
#   'start': 974,
#   'end': 994},
#  {'doc_id': '9497246', 'mention': 'ovarian cancer', 'start': 688, 'end': 702},
#  {'doc_id': '9497246',
#   'mention': 'ovarian cancer',
#   'start': 1736,
#   'end': 1750},
#  {'doc_id': '9506545',
#   'mention': 'Eye movement abnormalities',
#   'start': 0,
#   'end': 26},
#  {'doc_id': '9506545',
#   'mention': 'autosomal dominant cerebellar ataxia type I',
#   'start': 54,
#   'end': 97},
#  {'doc_id': '9506545',
#   'mention': 'autosomal dominant cerebellar ataxias type I',
#   'start': 259,
#   'end': 303},
#  {'doc_id': '9506545',
#   'mention': 'spinocerebellar ataxias 1',
#   'start': 304,
#   'end': 329},
#  {'doc_id': '9506545',
#   'mention': 'spinocerebellar ataxias 2',
#   'start': -1,
#   'end': -1},
#  {'doc_id': '9506545', 'mention': 'SCA1', 'start': 337, 'end': 341},
#  {'doc_id': '9506545', 'mention': 'SCA1', 'start': 416, 'end': 420},
#  {'doc_id': '9506545', 'mention': 'SCA1', 'start': 1081, 'end': 1085},
#  {'doc_id': '9506545', 'mention': 'SCA1', 'start': 1228, 'end': 1232},
#  {'doc_id': '9506545', 'mention': 'SCA2', 'start': 351, 'end': 355},
#  {'doc_id': '9506545', 'mention': 'SCA2', 'start': 537, 'end': 541},
#  {'doc_id': '9506545', 'mention': 'SCA2', 'start': 1098, 'end': 1102},
#  {'doc_id': '9506545', 'mention': 'SCA2', 'start': 1234, 'end': 1238},
#  {'doc_id': '9506545', 'mention': 'SCA3', 'start': 369, 'end': 373},
#  {'doc_id': '9506545', 'mention': 'SCA3', 'start': 816, 'end': 820},
#  {'doc_id': '9506545', 'mention': 'SCA3', 'start': 1133, 'end': 1137},
#  {'doc_id': '9506545', 'mention': 'SCA3', 'start': 1244, 'end': 1248},
#  {'doc_id': '9506545',
#   'mention': 'Machado-Joseph disease (MJD)',
#   'start': 374,
#   'end': 402},
#  {'doc_id': '9506545', 'mention': 'hypermetria', 'start': 482, 'end': 493},
#  {'doc_id': '9506545', 'mention': 'antisaccades', 'start': 163, 'end': 175},
#  {'doc_id': '9506545', 'mention': 'antisaccades', 'start': 612, 'end': 624},
#  {'doc_id': '9506545', 'mention': 'disease onset', 'start': 692, 'end': 705},
#  {'doc_id': '9506545',
#   'mention': 'gaze-evoked nystagmus',
#   'start': 822,
#   'end': 843},
#  {'doc_id': '9506545',
#   'mention': 'gaze-evoked nystagmus',
#   'start': 1011,
#   'end': 1032},
#  {'doc_id': '9506545',
#   'mention': 'saccade hypometria',
#   'start': 869,
#   'end': 887},
#  {'doc_id': '9506545', 'mention': 'diseases', 'start': 1281, 'end': 1289},
#  {'doc_id': '9521325',
#   'mention': 'idiopathic ventricular fibrillation',
#   'start': 42,
#   'end': 77},
#  {'doc_id': '9521325',
#   'mention': 'idiopathic ventricular fibrillation',
#   'start': 328,
#   'end': 363},
#  {'doc_id': '9521325',
#   'mention': 'Ventricular fibrillation',
#   'start': 79,
#   'end': 103},
#  {'doc_id': '9521325',
#   'mention': 'idiopathic ventricular fibrillation (IVF)',
#   'start': 328,
#   'end': 369},
#  {'doc_id': '9521325', 'mention': 'IVF', 'start': 365, 'end': 368},
#  {'doc_id': '9521325', 'mention': 'IVF', 'start': 391, 'end': 394},
#  {'doc_id': '9521325', 'mention': 'IVF', 'start': 604, 'end': 607},
#  {'doc_id': '9521325', 'mention': 'IVF', 'start': 640, 'end': 643},
#  {'doc_id': '9521325', 'mention': 'IVF', 'start': 954, 'end': 957},
#  {'doc_id': '9521325', 'mention': 'IVF', 'start': 1258, 'end': 1261},
#  {'doc_id': '9521325', 'mention': 'sudden death', 'start': 130, 'end': 142},
#  {'doc_id': '9521325', 'mention': 'sudden death', 'start': 552, 'end': 564},
#  {'doc_id': '9521325',
#   'mention': 'cardiac rhythm disturbance',
#   'start': 651,
#   'end': 677},
#  {'doc_id': '9521421',
#   'mention': 'mucopolysaccharidosis IVA',
#   'start': 27,
#   'end': 52},
#  {'doc_id': '9521421',
#   'mention': 'Mucopolysaccharidosis IVA (MPS IVA)',
#   'start': 173,
#   'end': 208},
#  {'doc_id': '9521421',
#   'mention': 'autosomal recessive lysosomal storage disorder',
#   'start': 215,
#   'end': 261},
#  {'doc_id': '9521421', 'mention': 'MPS IVA', 'start': 200, 'end': 207},
#  {'doc_id': '9521421', 'mention': 'MPS IVA', 'start': 476, 'end': 483},
#  {'doc_id': '9521421', 'mention': 'MPS IVA', 'start': 593, 'end': 600},
#  {'doc_id': '9521421', 'mention': 'MPS IVA', 'start': 1889, 'end': 1896},
#  {'doc_id': '9521421',
#   'mention': 'clinical phenotype',
#   'start': 515,
#   'end': 533},
#  {'doc_id': '9521421',
#   'mention': 'clinical phenotype',
#   'start': 669,
#   'end': 687},
#  {'doc_id': '9521421',
#   'mention': 'clinical phenotypes',
#   'start': 669,
#   'end': 688},
#  {'doc_id': '9521421', 'mention': 'severe', 'start': 508, 'end': 514},
#  {'doc_id': '9521421', 'mention': 'severe', 'start': 690, 'end': 696},
#  {'doc_id': '9521421', 'mention': 'severe', 'start': 998, 'end': 1004},
#  {'doc_id': '9521421', 'mention': 'intermediate', 'start': 708, 'end': 720},
#  {'doc_id': '9521421', 'mention': 'mild phenotype', 'start': 157, 'end': 171},
#  {'doc_id': '9521421',
#   'mention': 'mild phenotype',
#   'start': 1260,
#   'end': 1274},
#  {'doc_id': '9529364',
#   'mention': 'constitutional WT1 mutations',
#   'start': 18,
#   'end': 46},
#  {'doc_id': '9529364',
#   'mention': 'isolated diffuse mesangial sclerosis',
#   'start': 65,
#   'end': 101},
#  {'doc_id': '9529364',
#   'mention': 'Denys-Drash syndrome (DDS)',
#   'start': 356,
#   'end': 382},
#  {'doc_id': '9529364',
#   'mention': 'diffuse mesangial sclerosis (DMS)',
#   'start': 387,
#   'end': 420},
#  {'doc_id': '9529364',
#   'mention': 'pseudohermaphroditism',
#   'start': 437,
#   'end': 458},
#  {'doc_id': '9529364',
#   'mention': 'Wilms tumor (WT)',
#   'start': 466,
#   'end': 482},
#  {'doc_id': '9529364', 'mention': 'DDS', 'start': 378, 'end': 381},
#  {'doc_id': '9529364', 'mention': 'DDS', 'start': 502, 'end': 505},
#  {'doc_id': '9529364', 'mention': 'DDS', 'start': 704, 'end': 707},
#  {'doc_id': '9529364', 'mention': 'DDS', 'start': 996, 'end': 999},
#  {'doc_id': '9529364',
#   'mention': 'isolated DMS (IDMS)',
#   'start': 675,
#   'end': 694},
#  {'doc_id': '9529364',
#   'mention': 'urogenital abnormalities',
#   'start': 720,
#   'end': 744},
#  {'doc_id': '9529364', 'mention': 'WT', 'start': 33, 'end': 35},
#  {'doc_id': '9529364', 'mention': 'WT', 'start': 227, 'end': 229},
#  {'doc_id': '9529364', 'mention': 'WT', 'start': 479, 'end': 481},
#  {'doc_id': '9529364', 'mention': 'WT', 'start': 752, 'end': 754},
#  {'doc_id': '9529364', 'mention': 'WT', 'start': 766, 'end': 768},
#  {'doc_id': '9529364', 'mention': 'WT', 'start': 883, 'end': 885},
#  {'doc_id': '9529364', 'mention': 'WT', 'start': 1013, 'end': 1015},
#  {'doc_id': '9529364', 'mention': 'WT', 'start': 1206, 'end': 1208},
#  {'doc_id': '9529364', 'mention': 'WT1 mutations', 'start': 33, 'end': 46},
#  {'doc_id': '9529364', 'mention': 'WT1 mutations', 'start': 883, 'end': 896},
#  {'doc_id': '9529364', 'mention': 'WT1 mutations', 'start': 1013, 'end': 1026},
#  {'doc_id': '9529364', 'mention': 'IDMS', 'start': 689, 'end': 693},
#  {'doc_id': '9529364', 'mention': 'IDMS', 'start': 834, 'end': 838},
#  {'doc_id': '9529364', 'mention': 'IDMS', 'start': 864, 'end': 868},
#  {'doc_id': '9529364', 'mention': 'IDMS', 'start': 953, 'end': 957},
#  {'doc_id': '9529364', 'mention': 'IDMS', 'start': 1058, 'end': 1062},
#  {'doc_id': '9529364',
#   'mention': 'genetic heterogeneity of this disease',
#   'start': 1084,
#   'end': 1121},
#  {'doc_id': '9529364', 'mention': 'WT1 mutation', 'start': 33, 'end': 45},
#  {'doc_id': '9529364', 'mention': 'WT1 mutation', 'start': 883, 'end': 895},
#  {'doc_id': '9529364', 'mention': 'WT1 mutation', 'start': 1013, 'end': 1025},
#  {'doc_id': '9529364', 'mention': 'WT1 mutation', 'start': 1206, 'end': 1218},
#  {'doc_id': '9529364', 'mention': 'DMS', 'start': 416, 'end': 419},
#  {'doc_id': '9529364', 'mention': 'DMS', 'start': 684, 'end': 687},
#  {'doc_id': '9529364', 'mention': 'DMS', 'start': 690, 'end': 693},
#  {'doc_id': '9529364', 'mention': 'DMS', 'start': 835, 'end': 838},
#  {'doc_id': '9529364', 'mention': 'DMS', 'start': 865, 'end': 868},
#  {'doc_id': '9529364', 'mention': 'DMS', 'start': 954, 'end': 957},
#  {'doc_id': '9529364', 'mention': 'DMS', 'start': 1059, 'end': 1062},
#  {'doc_id': '9529364', 'mention': 'DMS', 'start': 1420, 'end': 1423},
#  {'doc_id': '9529364', 'mention': 'DMS', 'start': 1449, 'end': 1452},
#  {'doc_id': '9529364',
#   'mention': 'sexual ambiguity',
#   'start': 1569,
#   'end': 1585},
#  {'doc_id': '9529364', 'mention': 'mutations', 'start': 37, 'end': 46},
#  {'doc_id': '9529364', 'mention': 'mutations', 'start': 210, 'end': 219},
#  {'doc_id': '9529364', 'mention': 'mutations', 'start': 489, 'end': 498},
#  {'doc_id': '9529364', 'mention': 'mutations', 'start': 783, 'end': 792},
#  {'doc_id': '9529364', 'mention': 'mutations', 'start': 887, 'end': 896},
#  {'doc_id': '9529364', 'mention': 'mutations', 'start': 927, 'end': 936},
#  {'doc_id': '9529364', 'mention': 'mutations', 'start': 1017, 'end': 1026},
#  {'doc_id': '9529364', 'mention': 'mutations', 'start': 1244, 'end': 1253},
#  {'doc_id': '9529364', 'mention': 'mutations', 'start': 1295, 'end': 1304},
#  {'doc_id': '9529364', 'mention': 'mutations', 'start': 1389, 'end': 1398},
#  {'doc_id': '9529364', 'mention': 'mutations', 'start': 1483, 'end': 1492},
#  {'doc_id': '9529364', 'mention': 'mutations', 'start': 1653, 'end': 1662},
#  {'doc_id': '9536083', 'mention': 'BRCA1 mutation', 'start': 13, 'end': 27},
#  {'doc_id': '9536083',
#   'mention': 'BRCA1 mutation',
#   'start': 1152,
#   'end': 1166},
#  {'doc_id': '9536083',
#   'mention': 'breast and ovarian cancer',
#   'start': 197,
#   'end': 222},
#  {'doc_id': '9536083',
#   'mention': 'breast/ovarian cancer',
#   'start': 929,
#   'end': 950},
#  {'doc_id': '9546397',
#   'mention': 'hereditary hemochromatosis',
#   'start': 195,
#   'end': 221},
#  {'doc_id': '9546397', 'mention': 'hemochromatosis', 'start': 25, 'end': 40},
#  {'doc_id': '9546397', 'mention': 'hemochromatosis', 'start': 206, 'end': 221},
#  {'doc_id': '9546397', 'mention': 'hemochromatosis', 'start': 414, 'end': 429},
#  {'doc_id': '9546397',
#   'mention': 'hemochromatosis mutations',
#   'start': 414,
#   'end': 439},
#  {'doc_id': '9554743', 'mention': 'Wilson disease', 'start': 111, 'end': 125},
#  {'doc_id': '9554743', 'mention': 'Wilson disease', 'start': 277, 'end': 291},
#  {'doc_id': '9554743', 'mention': 'Wilson disease', 'start': 748, 'end': 762},
#  {'doc_id': '9563950',
#   'mention': 'myotonic dystrophy',
#   'start': 61,
#   'end': 79},
#  {'doc_id': '9563950', 'mention': 'DM', 'start': 101, 'end': 103},
#  {'doc_id': '9563950', 'mention': 'DM', 'start': 170, 'end': 172},
#  {'doc_id': '9563950', 'mention': 'DM', 'start': 192, 'end': 194},
#  {'doc_id': '9563950', 'mention': 'DM', 'start': 672, 'end': 674},
#  {'doc_id': '9563950', 'mention': 'DM', 'start': 858, 'end': 860},
#  {'doc_id': '9580132',
#   'mention': 'familial neurohypophyseal diabetes insipidus',
#   'start': 140,
#   'end': 184},
#  {'doc_id': '9580132',
#   'mention': 'Familial neurohypophyseal diabetes insipidus (FNDI)',
#   'start': 186,
#   'end': 237},
#  {'doc_id': '9580132', 'mention': 'FNDI', 'start': 232, 'end': 236},
#  {'doc_id': '9580132', 'mention': 'FNDI', 'start': 463, 'end': 467},
#  {'doc_id': '9580132', 'mention': 'FNDI', 'start': 1173, 'end': 1177},
#  {'doc_id': '9580132', 'mention': 'disease', 'start': 263, 'end': 270},
#  {'doc_id': '9585583',
#   'mention': 'Saethre-Chotzen syndrome',
#   'start': 25,
#   'end': 49},
#  {'doc_id': '9585583',
#   'mention': 'Saethre-Chotzen syndrome',
#   'start': 131,
#   'end': 155},
#  {'doc_id': '9585583',
#   'mention': 'Saethre-Chotzen syndrome',
#   'start': 561,
#   'end': 585},
#  {'doc_id': '9585583',
#   'mention': 'craniosynostosis',
#   'start': 198,
#   'end': 214},
#  {'doc_id': '9585583',
#   'mention': 'craniosynostotic condition',
#   'start': 1197,
#   'end': 1223},
#  {'doc_id': '9585583', 'mention': 'Saethre-Chotzen', 'start': 25, 'end': 40},
#  {'doc_id': '9585583', 'mention': 'Saethre-Chotzen', 'start': 131, 'end': 146},
#  {'doc_id': '9585583', 'mention': 'Saethre-Chotzen', 'start': 561, 'end': 576},
#  {'doc_id': '9585583',
#   'mention': 'Saethre-Chotzen',
#   'start': 1232,
#   'end': 1247},
#  {'doc_id': '9585583', 'mention': 'Crouzon', 'start': 1249, 'end': 1256},
#  {'doc_id': '9585583',
#   'mention': 'Pfeiffer syndromes',
#   'start': 1262,
#   'end': 1280},
#  {'doc_id': '9585605', 'mention': 'Angelman syndrome', 'start': 30, 'end': 47},
#  {'doc_id': '9585605', 'mention': 'Angelman syndrome', 'start': 58, 'end': 75},
#  {'doc_id': '9585605',
#   'mention': 'Angelman syndrome (AS)',
#   'start': 58,
#   'end': 80},
#  {'doc_id': '9585605', 'mention': 'AS', 'start': 77, 'end': 79},
#  {'doc_id': '9585605', 'mention': 'AS', 'start': 402, 'end': 404},
#  {'doc_id': '9585605', 'mention': 'AS', 'start': 981, 'end': 983},
#  {'doc_id': '9585605', 'mention': 'AS', 'start': 1025, 'end': 1027},
#  {'doc_id': '9585605', 'mention': 'AS', 'start': 1067, 'end': 1069},
#  {'doc_id': '9585605',
#   'mention': 'chromosome 15q11-q13 deletions',
#   'start': 94,
#   'end': 124},
#  {'doc_id': '9585605',
#   'mention': 'paternal uniparental disomy (UPD) 15',
#   'start': 148,
#   'end': 184},
#  {'doc_id': '9585605',
#   'mention': 'imprinting defects',
#   'start': 189,
#   'end': 207},
#  {'doc_id': '9585606', 'mention': 'Hemochromatosis', 'start': 96, 'end': 111},
#  {'doc_id': '9585606', 'mention': 'hemochromatosis', 'start': 4, 'end': 19},
#  {'doc_id': '9585606', 'mention': 'hemochromatosis', 'start': 231, 'end': 246},
#  {'doc_id': '9585606', 'mention': 'hemochromatosis', 'start': 473, 'end': 488},
#  {'doc_id': '9585611',
#   'mention': 'attenuated adenomatous polyposis coli',
#   'start': 35,
#   'end': 72},
#  {'doc_id': '9585611',
#   'mention': 'attenuated adenomatous polyposis coli',
#   'start': 140,
#   'end': 177},
#  {'doc_id': '9585611', 'mention': 'tumor', 'start': 101, 'end': 106},
#  {'doc_id': '9585611', 'mention': 'tumor', 'start': 1375, 'end': 1380},
#  {'doc_id': '9585611', 'mention': 'APC', 'start': 118, 'end': 121},
#  {'doc_id': '9585611', 'mention': 'APC', 'start': 180, 'end': 183},
#  {'doc_id': '9585611', 'mention': 'APC', 'start': 238, 'end': 241},
#  {'doc_id': '9585611', 'mention': 'APC', 'start': 429, 'end': 432},
#  {'doc_id': '9585611', 'mention': 'APC', 'start': 515, 'end': 518},
#  {'doc_id': '9585611', 'mention': 'APC', 'start': 570, 'end': 573},
#  {'doc_id': '9585611', 'mention': 'APC', 'start': 653, 'end': 656},
#  {'doc_id': '9585611', 'mention': 'APC', 'start': 759, 'end': 762},
#  {'doc_id': '9585611', 'mention': 'APC', 'start': 1261, 'end': 1264},
#  {'doc_id': '9585611', 'mention': 'APC', 'start': 1439, 'end': 1442},
#  {'doc_id': '9585611', 'mention': 'APC', 'start': 1473, 'end': 1476},
#  {'doc_id': '9585611',
#   'mention': 'attenuated adenomatous polyposis coli (AAPC)',
#   'start': 140,
#   'end': 184},
#  {'doc_id': '9585611',
#   'mention': 'familial adenomatous polyposis (FAP)',
#   'start': 199,
#   'end': 235},
#  {'doc_id': '9585611', 'mention': 'AAPC', 'start': 179, 'end': 183},
#  {'doc_id': '9585611', 'mention': 'AAPC', 'start': 237, 'end': 241},
#  {'doc_id': '9585611', 'mention': 'AAPC', 'start': 428, 'end': 432},
#  {'doc_id': '9585611', 'mention': 'AAPC', 'start': 569, 'end': 573},
#  {'doc_id': '9585611', 'mention': 'AAPC', 'start': 1260, 'end': 1264},
#  {'doc_id': '9585611', 'mention': 'AAPC', 'start': 1438, 'end': 1442},
#  {'doc_id': '9585611',
#   'mention': 'colorectal cancer',
#   'start': 321,
#   'end': 338},
#  {'doc_id': '9585611',
#   'mention': 'germ-line APC mutations',
#   'start': 643,
#   'end': 666},
#  {'doc_id': '9585611',
#   'mention': 'colorectal adenomas',
#   'start': 899,
#   'end': 918},
#  {'doc_id': '9585611',
#   'mention': 'colorectal adenomas',
#   'start': 1305,
#   'end': 1324},
#  {'doc_id': '9585611', 'mention': 'adenomas', 'start': 291, 'end': 299},
#  {'doc_id': '9585611', 'mention': 'adenomas', 'start': 910, 'end': 918},
#  {'doc_id': '9585611', 'mention': 'adenomas', 'start': 1132, 'end': 1140},
#  {'doc_id': '9585611', 'mention': 'adenomas', 'start': 1316, 'end': 1324},
#  {'doc_id': '9585611',
#   'mention': 'upper-gastrointestinal manifestations',
#   'start': 984,
#   'end': 1021},
#  {'doc_id': '9585611', 'mention': 'rectal polyp', 'start': 1329, 'end': 1341},
#  {'doc_id': '9585611',
#   'mention': 'desmoid tumors',
#   'start': 1367,
#   'end': 1381},
#  {'doc_id': '9585611', 'mention': 'FAP', 'start': 231, 'end': 234},
# ...
#  {'doc_id': '9703418', 'mention': 'C9 deficiency', 'start': 882, 'end': 895},
#  {'doc_id': '9703418',
#   'mention': 'meningococcal meningitis',
#   'start': 363,
#   'end': 387},
#  {'doc_id': '9703418', 'mention': 'C9-deficient', 'start': 319, 'end': 331},
#  {'doc_id': '9703418', 'mention': 'C9-deficient', 'start': 517, 'end': 529},
#  {'doc_id': '9703501',
#   'mention': 'oxidative DNA damage',
#   'start': 51,
#   'end': 71},
#  {'doc_id': '9703501',
#   'mention': 'oxidative DNA damage',
#   'start': 556,
#   'end': 576},
#  {'doc_id': '9703501',
#   'mention': 'oxidative DNA damage',
#   'start': 752,
#   'end': 772},
#  {'doc_id': '9703501',
#   'mention': 'breast and ovarian cancer',
#   'start': 77,
#   'end': 102},
#  {'doc_id': '9705283', 'mention': 'aniridia', 'start': 425, 'end': 433},
#  {'doc_id': '9705283', 'mention': 'aniridia', 'start': 592, 'end': 600},
#  {'doc_id': '9705283', 'mention': 'aniridia', 'start': 1524, 'end': 1532},
#  {'doc_id': '9705283', 'mention': 'Peters anomaly', 'start': 435, 'end': 449},
#  {'doc_id': '9705283',
#   'mention': 'autosomal dominant keratitis',
#   'start': 451,
#   'end': 479},
#  {'doc_id': '9705283',
#   'mention': 'familial foveal dysplasia',
#   'start': 485,
#   'end': 510},
#  {'doc_id': '9705283', 'mention': 'Aniridia', 'start': 757, 'end': 765},
#  {'doc_id': '9709714',
#   'mention': 'hypertrophic cardiomyopathy',
#   'start': 19,
#   'end': 46},
#  {'doc_id': '9709714',
#   'mention': 'hypertrophic cardiomyopathy',
#   'start': 431,
#   'end': 458},
#  {'doc_id': '9709714',
#   'mention': 'very-long-chain acyl-coenzyme A dehydrogenase (VLCAD) deficiency',
#   'start': -1,
#   'end': -1},
#  {'doc_id': '9709714',
#   'mention': 'VLCAD deficiency',
#   'start': 364,
#   'end': 380},
#  {'doc_id': '9709714',
#   'mention': 'VLCAD deficiency',
#   'start': 535,
#   'end': 551},
#  {'doc_id': '9709714',
#   'mention': 'VLCAD deficiency',
#   'start': 1061,
#   'end': 1077},
#  {'doc_id': '9709714', 'mention': 'hepatomegaly', 'start': 460, 'end': 472},
#  {'doc_id': '9709714', 'mention': 'encephalopathy', 'start': 474, 'end': 488},
#  {'doc_id': '9709714', 'mention': 'hypotonia', 'start': 494, 'end': 503},
#  {'doc_id': '9709714', 'mention': 'cardiomyopathy', 'start': 32, 'end': 46},
#  {'doc_id': '9709714', 'mention': 'cardiomyopathy', 'start': 444, 'end': 458},
#  {'doc_id': '9709714',
#   'mention': 'cardiomyopathy',
#   'start': 1149,
#   'end': 1163},
#  {'doc_id': '9714764',
#   'mention': 'insulin-dependent diabetes mellitus (IDDM)',
#   'start': 171,
#   'end': 213},
#  {'doc_id': '9714764', 'mention': 'diabetes', 'start': 189, 'end': 197},
#  {'doc_id': '9714764', 'mention': 'diabetes', 'start': 340, 'end': 348},
#  {'doc_id': '9724771', 'mention': 'colorectal tumors', 'start': 55, 'end': 72},
#  {'doc_id': '9724771',
#   'mention': 'colorectal tumors',
#   'start': 926,
#   'end': 943},
#  {'doc_id': '9724771',
#   'mention': 'familial adenomatous polyposis (FAP)',
#   'start': 122,
#   'end': 158},
#  {'doc_id': '9724771',
#   'mention': 'colorectal adenomas',
#   'start': 252,
#   'end': 271},
#  {'doc_id': '9724771',
#   'mention': 'colorectal adenomas',
#   'start': 549,
#   'end': 568},
#  {'doc_id': '9724771',
#   'mention': 'colorectal adenomas',
#   'start': 1041,
#   'end': 1060},
#  {'doc_id': '9724771',
#   'mention': 'colorectal adenomas',
#   'start': 1558,
#   'end': 1577},
#  {'doc_id': '9724771', 'mention': 'carcinoma', 'start': 276, 'end': 285},
#  {'doc_id': '9724771', 'mention': 'carcinoma', 'start': 1068, 'end': 1077},
#  {'doc_id': '9724771', 'mention': 'carcinoma', 'start': 1582, 'end': 1591},
#  {'doc_id': '9724771',
#   'mention': 'attenuated adenomatous polyposis coli',
#   'start': 366,
#   'end': 403},
#  {'doc_id': '9724771',
#   'mention': 'metaplastic polyps of the colorectum',
#   'start': 1392,
#   'end': 1428},
#  {'doc_id': '9724771',
#   'mention': 'colorectal cancer',
#   'start': 1677,
#   'end': 1694},
#  {'doc_id': '9729124',
#   'mention': 'congenital chloride diarrhea (CLD)',
#   'start': 31,
#   'end': 65},
#  {'doc_id': '9729124',
#   'mention': 'Congenital chloride diarrhea (CLD)',
#   'start': 72,
#   'end': 106},
#  {'doc_id': '9729124', 'mention': 'CLD', 'start': 61, 'end': 64},
#  {'doc_id': '9729124', 'mention': 'CLD', 'start': 102, 'end': 105},
#  {'doc_id': '9729124', 'mention': 'CLD', 'start': 249, 'end': 252},
#  {'doc_id': '9729124', 'mention': 'CLD', 'start': 643, 'end': 646},
#  {'doc_id': '9729124', 'mention': 'CLD', 'start': 900, 'end': 903},
#  {'doc_id': '9729124', 'mention': 'disease', 'start': 780, 'end': 787},
#  {'doc_id': '9729124',
#   'mention': 'Pendred syndrome gene (PDS)',
#   'start': 971,
#   'end': 998},
#  {'doc_id': '9731533', 'mention': 'cancer', 'start': 25, 'end': 31},
#  {'doc_id': '9731533', 'mention': 'cancer', 'start': 327, 'end': 333},
#  {'doc_id': '9731533', 'mention': 'cancer', 'start': 789, 'end': 795},
#  {'doc_id': '9731533', 'mention': 'cancer', 'start': 909, 'end': 915},
#  {'doc_id': '9731533',
#   'mention': 'familial adenomatous polyposis (FAP)',
#   'start': 132,
#   'end': 168},
#  {'doc_id': '9731533',
#   'mention': 'colorectal cancer (CRC)',
#   'start': 316,
#   'end': 339},
#  {'doc_id': '9731533', 'mention': 'tumours', 'start': 401, 'end': 408},
#  {'doc_id': '9731533', 'mention': 'CRC', 'start': 335, 'end': 338},
#  {'doc_id': '9731533', 'mention': 'CRC', 'start': 741, 'end': 744},
#  {'doc_id': '9731533', 'mention': 'colorectal', 'start': 316, 'end': 326},
#  {'doc_id': '9731533', 'mention': 'colorectal', 'start': 880, 'end': 890},
#  {'doc_id': '9731533', 'mention': 'breast', 'start': 892, 'end': 898},
#  {'doc_id': '9731533', 'mention': 'cancers', 'start': 909, 'end': 916},
#  {'doc_id': '9733027', 'mention': 'Friedreich ataxia', 'start': 24, 'end': 41},
#  {'doc_id': '9733027',
#   'mention': 'Friedreich ataxia',
#   'start': 124,
#   'end': 141},
#  {'doc_id': '9733027', 'mention': 'FRDA', 'start': 113, 'end': 117},
#  {'doc_id': '9733027', 'mention': 'FRDA', 'start': 225, 'end': 229},
#  {'doc_id': '9744473',
#   'mention': 'metachromatic leukodystrophy',
#   'start': 53,
#   'end': 81},
#  {'doc_id': '9744473',
#   'mention': 'metachromatic leukodystrophy',
#   'start': 143,
#   'end': 171},
#  {'doc_id': '9744473',
#   'mention': 'arylsulfatase A (ARSA)',
#   'start': 97,
#   'end': 119},
#  {'doc_id': '9744473',
#   'mention': 'metachromatic leukodystrophy (MLD)',
#   'start': 143,
#   'end': 177},
#  {'doc_id': '9744473', 'mention': 'MLD', 'start': 173, 'end': 176},
#  {'doc_id': '9744473', 'mention': 'MLD', 'start': 227, 'end': 230},
#  {'doc_id': '9744473', 'mention': 'MLD', 'start': 320, 'end': 323},
#  {'doc_id': '9744473', 'mention': 'MLD', 'start': 750, 'end': 753},
#  {'doc_id': '9770531',
#   'mention': 'renal cell carcinoma',
#   'start': 56,
#   'end': 76},
#  {'doc_id': '9770531',
#   'mention': 'renal cell carcinoma',
#   'start': 219,
#   'end': 239},
#  {'doc_id': '9770531',
#   'mention': 'renal cell carcinoma',
#   'start': 750,
#   'end': 770},
#  {'doc_id': '9770531',
#   'mention': 'von Hippel-Lindau (VHL) -mediated carcinogenesis',
#   'start': 161,
#   'end': 209},
#  {'doc_id': '9770531', 'mention': 'cancers', 'start': 1178, 'end': 1185},
#  {'doc_id': '9771706', 'mention': 'diabetes mellitus', 'start': 68, 'end': 85},
#  {'doc_id': '9771706',
#   'mention': 'diabetes mellitus',
#   'start': 265,
#   'end': 282},
#  {'doc_id': '9771706',
#   'mention': 'optic atrophy (Wolfram syndrome)',
#   'start': 90,
#   'end': 122},
#  {'doc_id': '9771706',
#   'mention': 'Wolfram syndrome (WFS; OMIM 222300)',
#   'start': 124,
#   'end': 159},
#  {'doc_id': '9771706', 'mention': 'optic atrophy', 'start': 90, 'end': 103},
#  {'doc_id': '9771706', 'mention': 'optic atrophy', 'start': 299, 'end': 312},
#  {'doc_id': '9771706', 'mention': 'WFS', 'start': 142, 'end': 145},
#  {'doc_id': '9771706', 'mention': 'WFS', 'start': 458, 'end': 461},
#  {'doc_id': '9771706', 'mention': 'WFS', 'start': 548, 'end': 551},
#  {'doc_id': '9771706', 'mention': 'WFS', 'start': 642, 'end': 645},
#  {'doc_id': '9771706', 'mention': 'WFS', 'start': 720, 'end': 723},
#  {'doc_id': '9774970', 'mention': 'BRCA1', 'start': 47, 'end': 52},
#  {'doc_id': '9774970', 'mention': 'BRCA1', 'start': 116, 'end': 121},
#  {'doc_id': '9774970', 'mention': 'BRCA1', 'start': 294, 'end': 299},
#  {'doc_id': '9774970', 'mention': 'BRCA1', 'start': 463, 'end': 468},
#  {'doc_id': '9774970', 'mention': 'BRCA1', 'start': 600, 'end': 605},
#  {'doc_id': '9774970', 'mention': 'BRCA2', 'start': 57, 'end': 62},
#  {'doc_id': '9774970', 'mention': 'BRCA2', 'start': 126, 'end': 131},
#  {'doc_id': '9774970', 'mention': 'BRCA2', 'start': 304, 'end': 309},
#  {'doc_id': '9774970', 'mention': 'BRCA2', 'start': 480, 'end': 485},
#  {'doc_id': '9774970', 'mention': 'BRCA2', 'start': 610, 'end': 615},
#  {'doc_id': '9774970', 'mention': 'familial', 'start': 158, 'end': 166},
#  {'doc_id': '9774970',
#   'mention': 'breast and/or ovarian cancer',
#   'start': 180,
#   'end': 208},
#  {'doc_id': '9774970',
#   'mention': 'breast and/or ovarian cancer',
#   'start': 845,
#   'end': 873},
#  {'doc_id': '9774970',
#   'mention': 'hereditary breast and/or ovarian cancer',
#   'start': 834,
#   'end': 873},
#  {'doc_id': '9790667',
#   'mention': 'cerebrotendinous xanthomatosis (CTX)',
#   'start': 269,
#   'end': 305},
#  {'doc_id': '9790667',
#   'mention': 'deficiency in the sterol 27-hydroxylase activity',
#   'start': 438,
#   'end': 486},
#  {'doc_id': '9790667',
#   'mention': 'deficiency in the sterol 27-hydroxylase activity',
#   'start': 1364,
#   'end': 1412},
#  {'doc_id': '9792409',
#   'mention': 'ataxia-telangiectasia (A-T)',
#   'start': 180,
#   'end': 207},
#  {'doc_id': '9792409', 'mention': 'A-T', 'start': 203, 'end': 206},
#  {'doc_id': '9792409', 'mention': 'A-T', 'start': 284, 'end': 287},
#  {'doc_id': '9792409', 'mention': 'A-T', 'start': 1019, 'end': 1022},
#  {'doc_id': '9792409', 'mention': 'A-T', 'start': 1077, 'end': 1080},
#  {'doc_id': '9792409', 'mention': 'A-T', 'start': 1526, 'end': 1529},
#  {'doc_id': '9792409', 'mention': 'classical A-T', 'start': 274, 'end': 287},
#  {'doc_id': '9792409', 'mention': 'classical A-T', 'start': 1516, 'end': 1529},
#  {'doc_id': '9792860',
#   'mention': 'autosomal recessive Alport syndrome',
#   'start': 89,
#   'end': 124},
#  {'doc_id': '9792860',
#   'mention': 'autosomal recessive Alport syndrome',
#   'start': 716,
#   'end': 751},
#  {'doc_id': '9792861', 'mention': 'breast cancer', 'start': 138, 'end': 151},
#  {'doc_id': '9792861', 'mention': 'breast cancer', 'start': 210, 'end': 223},
#  {'doc_id': '9792861', 'mention': 'breast cancer', 'start': 967, 'end': 980},
#  {'doc_id': '9792861', 'mention': 'breast cancer', 'start': 1029, 'end': 1042},
#  {'doc_id': '9792861', 'mention': 'breast cancer', 'start': 1453, 'end': 1466},
#  {'doc_id': '9792861',
#   'mention': 'breast/ovarian cancer',
#   'start': 228,
#   'end': 249},
#  {'doc_id': '9792861',
#   'mention': 'breast/ovarian cancer',
#   'start': 1471,
#   'end': 1492},
#  {'doc_id': '9792861', 'mention': 'ovarian cancer', 'start': 64, 'end': 78},
#  {'doc_id': '9792861', 'mention': 'ovarian cancer', 'start': 235, 'end': 249},
#  {'doc_id': '9792861', 'mention': 'ovarian cancer', 'start': 807, 'end': 821},
#  {'doc_id': '9792861',
#   'mention': 'ovarian cancer',
#   'start': 1478,
#   'end': 1492},
#  {'doc_id': '9800909',
#   'mention': 'cognitive impairment',
#   'start': 56,
#   'end': 76},
#  {'doc_id': '9800909',
#   'mention': 'cognitive impairment',
#   'start': 288,
#   'end': 308},
#  {'doc_id': '9800909',
#   'mention': 'cognitive impairment',
#   'start': 912,
#   'end': 932},
#  {'doc_id': '9800909',
#   'mention': 'cognitive impairment',
#   'start': 1226,
#   'end': 1246},
#  {'doc_id': '9800909',
#   'mention': 'Duchenne muscular dystrophy',
#   'start': 80,
#   'end': 107},
#  {'doc_id': '9800909',
#   'mention': 'Duchenne muscular dystrophy',
#   'start': 205,
#   'end': 232},
#  {'doc_id': '9800909',
#   'mention': 'Duchenne muscular dystrophy (DMD)',
#   'start': 205,
#   'end': 238},
#  {'doc_id': '9800909',
#   'mention': 'cerebral dysfunction',
#   'start': 1039,
#   'end': 1059},
#  {'doc_id': '9800909', 'mention': 'DMD', 'start': 234, 'end': 237},
#  {'doc_id': '9800909', 'mention': 'DMD', 'start': 326, 'end': 329},
#  {'doc_id': '9800909', 'mention': 'DMD', 'start': 481, 'end': 484},
#  {'doc_id': '9800909', 'mention': 'DMD', 'start': 1168, 'end': 1171},
#  {'doc_id': '9800909', 'mention': 'DMD', 'start': 1263, 'end': 1266},
#  {'doc_id': '9831355',
#   'mention': 'hereditary non-polyposis colorectal cancer',
#   'start': 59,
#   'end': 101},
#  {'doc_id': '9831355',
#   'mention': 'hereditary non-polyposis colorectal cancer',
#   'start': 133,
#   'end': 175},
#  {'doc_id': '9831355',
#   'mention': 'hereditary non-polyposis colorectal cancer (HNPCC)',
#   'start': 133,
#   'end': 183},
#  {'doc_id': '9831355',
#   'mention': 'colorectal cancer',
#   'start': 84,
#   'end': 101},
#  {'doc_id': '9831355',
#   'mention': 'colorectal cancer',
#   'start': 158,
#   'end': 175},
#  {'doc_id': '9831355',
#   'mention': 'colorectal cancer',
#   'start': 325,
#   'end': 342},
#  {'doc_id': '9831355', 'mention': 'cancer', 'start': 95, 'end': 101},
#  {'doc_id': '9831355', 'mention': 'cancer', 'start': 169, 'end': 175},
#  {'doc_id': '9831355', 'mention': 'cancer', 'start': 336, 'end': 342},
#  {'doc_id': '9831355', 'mention': 'cancer', 'start': 622, 'end': 628},
#  {'doc_id': '9843038',
#   'mention': 'hereditary coproporphyria',
#   'start': 65,
#   'end': 90},
#  {'doc_id': '9843038',
#   'mention': 'Hereditary coproporphyria (HCP)',
#   'start': 99,
#   'end': 130},
#  {'doc_id': '9843038',
#   'mention': 'autosomal dominant disease',
#   'start': 137,
#   'end': 163},
#  {'doc_id': '9843038', 'mention': 'HCP', 'start': 126, 'end': 129},
#  {'doc_id': '9843038', 'mention': 'HCP', 'start': 320, 'end': 323},
#  {'doc_id': '9848786',
#   'mention': 'Human complement factor H deficiency',
#   'start': 0,
#   'end': 36},
#  {'doc_id': '9848786',
#   'mention': 'hemolytic uremic syndrome',
#   'start': 53,
#   'end': 78},
#  {'doc_id': '9848786',
#   'mention': 'hemolytic uremic syndrome',
#   'start': 296,
#   'end': 321},
#  {'doc_id': '9848786',
#   'mention': 'idiopathic hemolytic uremic syndrome (HUS)',
#   'start': 285,
#   'end': 327},
#  {'doc_id': '9848786',
#   'mention': 'homozygous deficiency',
#   'start': 361,
#   'end': 382},
#  {'doc_id': '9848786',
#   'mention': 'homozygous deficiency',
#   'start': 627,
#   'end': 648},
#  {'doc_id': '9848786',
#   'mention': 'Factor H deficiency',
#   'start': 891,
#   'end': 910},
#  {'doc_id': '9848786',
#   'mention': 'complement deficiency',
#   'start': 923,
#   'end': 944},
#  {'doc_id': '9848786', 'mention': 'HUS', 'start': 323, 'end': 326},
#  {'doc_id': '9848786', 'mention': 'HUS', 'start': 961, 'end': 964},
#  {'doc_id': '9848786', 'mention': 'HUS', 'start': 1061, 'end': 1064},
#  {'doc_id': '9848786',
#   'mention': 'idiopathic HUS',
#   'start': 1050,
#   'end': 1064},
#  {'doc_id': '9852676',
#   'mention': 'myotonic dystrophy',
#   'start': 57,
#   'end': 75},
#  {'doc_id': '9852676',
#   'mention': 'myotonic dystrophy',
#   'start': 144,
#   'end': 162},
#  {'doc_id': '9852676',
#   'mention': 'myotonic dystrophy (DM)',
#   'start': 144,
#   'end': 167},
#  {'doc_id': '9852676', 'mention': 'DM', 'start': 164, 'end': 166},
#  {'doc_id': '9852676', 'mention': 'DM', 'start': 306, 'end': 308},
#  {'doc_id': '9852676', 'mention': 'DM', 'start': 370, 'end': 372},
#  {'doc_id': '9852676', 'mention': 'DM', 'start': 524, 'end': 526},
#  {'doc_id': '9852676', 'mention': 'DM', 'start': 718, 'end': 720},
#  {'doc_id': '9852676', 'mention': 'DM', 'start': 917, 'end': 919},
#  {'doc_id': '9852676', 'mention': 'DM', 'start': 1258, 'end': 1260},
#  {'doc_id': '9852676',
#   'mention': 'Friedreichs ataxia',
#   'start': 1265,
#   'end': 1283},
#  {'doc_id': '9856498', 'mention': 'C6 deficiency', 'start': 23, 'end': 36},
#  {'doc_id': '9856498', 'mention': 'C6 deficiency', 'start': 289, 'end': 302},
#  {'doc_id': '9856498',
#   'mention': 'Meningococcal disease',
#   'start': 210,
#   'end': 231},
#  {'doc_id': '9856498',
#   'mention': 'total C6 deficiency',
#   'start': 283,
#   'end': 302},
#  {'doc_id': '9856498', 'mention': 'C6Q0', 'start': 304, 'end': 308},
#  {'doc_id': '9856498', 'mention': 'C6Q0', 'start': 1048, 'end': 1052},
#  {'doc_id': '9856498',
#   'mention': 'total deficiency',
#   'start': 485,
#   'end': 501},
#  {'doc_id': '9856498', 'mention': 'C6-deficient', 'start': 1150, 'end': 1162},
#  {'doc_id': '9856499', 'mention': 'C7 deficiency', 'start': 11, 'end': 24},
#  ...]

# %%
df = pd.DataFrame(spans)
df.to_csv('predictions.tsv', sep="\t",index=False)

# %%
pred_df = pd.read_csv("D:/prompting/one_shot/predictions.tsv", sep="\t")
gold_df = pd.read_csv("D:/OGER/OGER/data/ncbi_annotations/gold_annotations.tsv", sep="\t")

# %%
def exact_match(pred, gold):
    return (
        pred['doc_id'] == gold['doc_id'] and
        pred['start'] == gold['start'] and
        pred['end'] == gold['end'] 
    )

def partial_match(pred, gold):
    return (
        pred['doc_id'] == gold['doc_id'] and
        not (pred['end'] <= gold['start'] or pred['start'] >= gold['end']) 
    )

# %%
def evaluate(pred_df, gold_df, match_func):
    tp = 0
    matched_gold = set()

    for _, pred_row in pred_df.iterrows():
        match_found = False
        for idx, gold_row in gold_df.iterrows():
            if idx in matched_gold:
                continue
            if match_func(pred_row, gold_row):
                tp += 1
                matched_gold.add(idx)
                match_found = True
                break

    fp = len(pred_df) - tp
    fn = len(gold_df) - tp

    precision = tp / (tp + fp) if tp + fp else 0.0
    recall = tp / (tp + fn) if tp + fn else 0.0
    f1 = 2 * precision * recall / (precision + recall) if precision + recall else 0.0

    return precision, recall, f1, fp, fn, tp

# %%
exact_precision, exact_recall, exact_f1, exact_fp, exact_fn, exact_tp = evaluate(pred_df, gold_df, exact_match)
partial_precision, partial_recall, partial_f1, partial_fp, partial_fn, partial_tp = evaluate(pred_df, gold_df, partial_match)

print(f"Exact Match: P={exact_precision:.6f}, R={exact_recall:.6f}, F1={exact_f1:.6f}, fp={exact_fp:.6f}, fn={exact_fn:.6f}, tp={exact_tp:.6f}")
print(f"Partial Match: P={partial_precision:.6f}, R={partial_recall:.6f}, F1={partial_f1:.6f}, fp={partial_fp:.6f}, fn={partial_fn:.6f}, tp={partial_tp:.6f}")
# Out:
# Exact Match: P=0.558431, R=0.696875, F1=0.620019, fp=529.000000, fn=291.000000, tp=669.000000
# Partial Match: P=0.661102, R=0.825000, F1=0.734013, fp=406.000000, fn=168.000000, tp=792.000000
