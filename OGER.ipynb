# %%
# !pip install bottle lxml NLTK

# %%
import csv
import os
from collections import defaultdict
import pandas as pd

from oger.doc.document import Collection
from oger.ctrl.router import Router, PipelineServer

# %%
import sys
sys.path.append("D:/OGER/OGER")

# %%
with open("D:/OGER/CTD/CTD.csv", 'r', encoding='utf-8') as f:
    sample = f.readline()
    print(repr(sample))
# Out:
# 'cui\tresource\toriginal_id\tterm\tpreferred_term\tentity_type\n'

# %%
def load_ncbi_corpus(txt_path):
    texts = defaultdict(dict)  
    annotations = defaultdict(list) 

    with open(txt_path, 'r', encoding='utf-8') as f:
        for line in f:
            if '|t|' in line or '|a|' in line:
                pmid, part, content = line.strip().split('|', maxsplit=2)
                texts[pmid][part] = content
            elif '\t' in line:
                pmid, start, end, mention, ent_type, concept_id = line.strip().split('\t')
                annotations[pmid].append((int(start), int(end), mention, ent_type, concept_id))

    combined_texts = {
        pmid: texts[pmid].get('t', '') + ' ' + texts[pmid].get('a', '')
        for pmid in texts
    }

    return combined_texts, annotations

# %%
texts, gold_annotations = load_ncbi_corpus("D:/scispacy/NCBItestset_corpus/NCBItestset_corpus.txt")

# %%
os.makedirs("data/ncbi_texts", exist_ok=True)

for pmid, text in texts.items():
    with open(f"data/ncbi_texts/{pmid}.txt", "w", encoding="utf-8") as f:
        f.write(text)

os.makedirs("data/ncbi_annotations", exist_ok=True)

with open("data/ncbi_annotations/gold_annotations.tsv", "w", newline='', encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile, delimiter='\t')
    writer.writerow(['pmid', 'start', 'end', 'mention', 'entity_type', 'concept_id'])  

    for pmid, annots in gold_annotations.items():
        for start, end, mention, entity_type, concept_id in annots:
            writer.writerow([pmid, start, end, mention, entity_type, concept_id])

print("Data and annotations saved successfully!")
# Out:
# Data and annotations saved successfully!

# %% [markdown]
# Applying OGER using python library:

# %%
conf = Router(termlist_path='D:/OGER/CTD/CTD.tsv')
pl = PipelineServer(conf)

# %%
text_directory = "D:/OGER/OGER/data/ncbi_texts"

documents = []
for file_name in os.listdir(text_directory):
    if file_name.endswith('.txt'):
        file_path = os.path.join(text_directory, file_name)
        doc = pl.load_one(file_path, 'txt')  
        pmid = file_name.replace('.txt', '')
        doc.id = pmid  
        documents.append(doc)


doc_collection = Collection.from_iterable(documents, id_="ncbi_collection")

pl.process(doc_collection)

all_predictions = {}

for doc in doc_collection:
    pmid = doc.id
    all_predictions[pmid] = []
    
    for entity in doc.iter_entities():
        all_predictions[pmid].append({
            "text": entity.text,
            "start": entity.start,
            "end": entity.end,
            "concept_id": entity.cid
        })
# Out:
# Recognizers configuration: (<oger.ctrl.parameters.ERParams object at 0x000002711F201BA0>,)
# Initializing EntityRecognizer with config: <oger.ctrl.parameters.ERParams object at 0x000002711F201BA0>

# %%
all_predictions
# Out:
# {'9288106': [{'text': 'ataxia',
#    'start': 40,
#    'end': 46,
#    'concept_id': 'D001259'},
#   {'text': 'ataxia-telangiectasia',
#    'start': 40,
#    'end': 61,
#    'concept_id': 'D001260'},
#   {'text': 'telangiectasia', 'start': 47, 'end': 61, 'concept_id': 'D013684'},
#   {'text': 'Ataxia', 'start': 99, 'end': 105, 'concept_id': 'D001259'},
#   {'text': 'Ataxia-telangiectasia',
#    'start': 99,
#    'end': 120,
#    'concept_id': 'D001260'},
#   {'text': 'telangiectasia',
#    'start': 106,
#    'end': 120,
#    'concept_id': 'D013684'},
#   {'text': 'cancer', 'start': 235, 'end': 241, 'concept_id': 'D009369'},
#   {'text': 'neoplasias', 'start': 263, 'end': 273, 'concept_id': 'D009369'},
#   {'text': 'chromosomal instability',
#    'start': 351,
#    'end': 374,
#    'concept_id': 'D043171'},
#   {'text': 'malignancy', 'start': 483, 'end': 493, 'concept_id': 'D009369'},
#   {'text': 'lymphomas', 'start': 1329, 'end': 1338, 'concept_id': 'D008223'},
#   {'text': 'NHL', 'start': 1342, 'end': 1345, 'concept_id': 'D008228'},
#   {'text': 'NHL', 'start': 1355, 'end': 1358, 'concept_id': 'D008228'},
#   {'text': 'was', 'start': 1682, 'end': 1685, 'concept_id': 'D014923'}],
#  '9294109': [{'text': 'Myotonic dystrophy',
#    'start': 0,
#    'end': 18,
#    'concept_id': 'D009223'},
#   {'text': 'Myotonic dystrophy',
#    'start': 114,
#    'end': 132,
#    'concept_id': 'D009223'}],
#  '9311732': [{'text': 'RB1', 'start': 15, 'end': 18, 'concept_id': 'D012175'},
#   {'text': 'retinoblastoma', 'start': 71, 'end': 85, 'concept_id': 'D012175'},
#   {'text': 'retinoblastoma',
#    'start': 129,
#    'end': 143,
#    'concept_id': 'D012175'},
#   {'text': 'tumor', 'start': 145, 'end': 150, 'concept_id': 'D009369'},
#   {'text': 'RB1', 'start': 223, 'end': 226, 'concept_id': 'D012175'},
#   {'text': 'can', 'start': 265, 'end': 268, 'concept_id': 'C567382'},
#   {'text': 'retinoblastoma',
#    'start': 278,
#    'end': 292,
#    'concept_id': 'D012175'},
#   {'text': 'RB1', 'start': 384, 'end': 387, 'concept_id': 'D012175'},
#   {'text': 'retinoblastoma',
#    'start': 440,
#    'end': 454,
#    'concept_id': 'D012175'},
#   {'text': 'tumor', 'start': 503, 'end': 508, 'concept_id': 'D009369'},
#   {'text': 'tumors', 'start': 533, 'end': 539, 'concept_id': 'D009369'},
#   {'text': 'tumors', 'start': 742, 'end': 748, 'concept_id': 'D009369'},
#   {'text': 'tumors', 'start': 894, 'end': 900, 'concept_id': 'D009369'},
#   {'text': 'tumors', 'start': 928, 'end': 934, 'concept_id': 'D009369'},
#   {'text': 'was', 'start': 961, 'end': 964, 'concept_id': 'D014923'},
#   {'text': 'tumors', 'start': 997, 'end': 1003, 'concept_id': 'D009369'},
#   {'text': 'tumors', 'start': 1093, 'end': 1099, 'concept_id': 'D009369'},
#   {'text': 'tumors', 'start': 1233, 'end': 1239, 'concept_id': 'D009369'},
#   {'text': 'was', 'start': 1343, 'end': 1346, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 1499, 'end': 1502, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 1582, 'end': 1585, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 1734, 'end': 1737, 'concept_id': 'D014923'},
#   {'text': 'tumors', 'start': 1792, 'end': 1798, 'concept_id': 'D009369'},
#   {'text': 'retinoblastoma',
#    'start': 1839,
#    'end': 1853,
#    'concept_id': 'D012175'},
#   {'text': 'retinoblastoma',
#    'start': 1939,
#    'end': 1953,
#    'concept_id': 'D012175'}],
#  '932197': [{'text': 'systemic lupus erythematosus',
#    'start': 279,
#    'end': 307,
#    'concept_id': 'D008180'},
#   {'text': 'was', 'start': 392, 'end': 395, 'concept_id': 'D014923'},
#   {'text': 'disease', 'start': 637, 'end': 644, 'concept_id': 'D004194'},
#   {'text': 'was', 'start': 646, 'end': 649, 'concept_id': 'D014923'},
#   {'text': 'C5 deficiency', 'start': 983, 'end': 996, 'concept_id': 'C537005'},
#   {'text': 'C5D', 'start': 1069, 'end': 1072, 'concept_id': 'C537005'},
#   {'text': 'was', 'start': 1159, 'end': 1162, 'concept_id': 'D014923'},
#   {'text': 'C5D', 'start': 1257, 'end': 1260, 'concept_id': 'C537005'},
#   {'text': 'C5D', 'start': 1426, 'end': 1429, 'concept_id': 'C537005'},
#   {'text': 'membranous glomerulonephritis',
#    'start': 1619,
#    'end': 1648,
#    'concept_id': 'D015433'},
#   {'text': 'glomerulonephritis',
#    'start': 1630,
#    'end': 1648,
#    'concept_id': 'D005921'},
#   {'text': 'vasculitis', 'start': 1650, 'end': 1660, 'concept_id': 'D014657'},
#   {'text': 'arthritis', 'start': 1666, 'end': 1675, 'concept_id': 'D001168'},
#   {'text': 'bacterial infections',
#    'start': 1769,
#    'end': 1789,
#    'concept_id': 'D001424'},
#   {'text': 'infections', 'start': 1779, 'end': 1789, 'concept_id': 'D007239'},
#   {'text': 'C5D', 'start': 1916, 'end': 1919, 'concept_id': 'C537005'},
#   {'text': 'leukocytosis',
#    'start': 2014,
#    'end': 2026,
#    'concept_id': 'D007964'},
#   {'text': 'infection', 'start': 2043, 'end': 2052, 'concept_id': 'D007239'}],
#  '9336417': [{'text': 'ankylosing spondylitis',
#    'start': 18,
#    'end': 40,
#    'concept_id': 'D013167'},
#   {'text': 'spondylitis', 'start': 29, 'end': 40, 'concept_id': 'D013166'},
#   {'text': 'ankylosing spondylitis',
#    'start': 199,
#    'end': 221,
#    'concept_id': 'D013167'},
#   {'text': 'spondylitis', 'start': 210, 'end': 221, 'concept_id': 'D013166'},
#   {'text': 'Rheumatic Diseases',
#    'start': 304,
#    'end': 322,
#    'concept_id': 'D012216'},
#   {'text': 'Diseases', 'start': 314, 'end': 322, 'concept_id': 'D004194'},
#   {'text': 'Diseases', 'start': 314, 'end': 322, 'concept_id': 'C'},
#   {'text': 'disease', 'start': 415, 'end': 422, 'concept_id': 'D004194'},
#   {'text': 'was', 'start': 432, 'end': 435, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 540, 'end': 543, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 628, 'end': 631, 'concept_id': 'D014923'},
#   {'text': 'disease', 'start': 863, 'end': 870, 'concept_id': 'D004194'},
#   {'text': 'disease', 'start': 1055, 'end': 1062, 'concept_id': 'D004194'},
#   {'text': 'all', 'start': 1073, 'end': 1076, 'concept_id': 'D054198'},
#   {'text': 'disease', 'start': 1084, 'end': 1091, 'concept_id': 'D004194'},
#   {'text': 'disease', 'start': 1131, 'end': 1138, 'concept_id': 'D004194'},
#   {'text': 'disease', 'start': 1235, 'end': 1242, 'concept_id': 'D004194'},
#   {'text': 'disease', 'start': 1272, 'end': 1279, 'concept_id': 'D004194'},
#   {'text': 'was', 'start': 1292, 'end': 1295, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 1361, 'end': 1364, 'concept_id': 'D014923'},
#   {'text': 'disease', 'start': 1588, 'end': 1595, 'concept_id': 'D004194'},
#   {'text': 'genetic susceptibility',
#    'start': 1667,
#    'end': 1689,
#    'concept_id': 'D020022'}],
#  '9342365': [{'text': 'ovarian cancer',
#    'start': 174,
#    'end': 188,
#    'concept_id': 'D010051'},
#   {'text': 'cancer', 'start': 182, 'end': 188, 'concept_id': 'D009369'},
#   {'text': 'tumor', 'start': 241, 'end': 246, 'concept_id': 'D009369'},
#   {'text': 'tumor', 'start': 1403, 'end': 1408, 'concept_id': 'D009369'}],
#  '9358014': [{'text': 'HFE', 'start': 26, 'end': 29, 'concept_id': 'D006432'},
#   {'text': 'hemochromatosis',
#    'start': 106,
#    'end': 121,
#    'concept_id': 'D006432'},
#   {'text': 'hemochromatosis',
#    'start': 106,
#    'end': 121,
#    'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 198, 'end': 201, 'concept_id': 'D006432'},
#   {'text': 'was', 'start': 617, 'end': 620, 'concept_id': 'D014923'},
#   {'text': 'HFE', 'start': 890, 'end': 893, 'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 999, 'end': 1002, 'concept_id': 'D006432'},
#   {'text': 'cancer', 'start': 1048, 'end': 1054, 'concept_id': 'D009369'}],
#  '9360520': [{'text': 'Autosomal dominant',
#    'start': 0,
#    'end': 18,
#    'concept_id': 'C566739'},
#   {'text': 'neurohypophyseal diabetes insipidus',
#    'start': 19,
#    'end': 54,
#    'concept_id': 'D020790'},
#   {'text': 'diabetes insipidus',
#    'start': 36,
#    'end': 54,
#    'concept_id': 'D003919'},
#   {'text': 'Autosomal dominant',
#    'start': 131,
#    'end': 149,
#    'concept_id': 'C566739'},
#   {'text': 'neurohypophyseal diabetes insipidus',
#    'start': 150,
#    'end': 185,
#    'concept_id': 'D020790'},
#   {'text': 'diabetes insipidus',
#    'start': 167,
#    'end': 185,
#    'concept_id': 'D003919'},
#   {'text': 'disease', 'start': 210, 'end': 217, 'concept_id': 'D004194'},
#   {'text': 'diabetes insipidus',
#    'start': 453,
#    'end': 471,
#    'concept_id': 'D003919'},
#   {'text': 'at 1', 'start': 472, 'end': 476, 'concept_id': 'D001260'},
#   {'text': 'disease', 'start': 515, 'end': 522, 'concept_id': 'D004194'},
#   {'text': 'all', 'start': 802, 'end': 805, 'concept_id': 'D054198'},
#   {'text': 'was', 'start': 937, 'end': 940, 'concept_id': 'D014923'}],
#  '9371490': [{'text': 'PTEN', 'start': 25, 'end': 29, 'concept_id': 'D006223'},
#   {'text': 'MMAC1', 'start': 30, 'end': 35, 'concept_id': 'D006223'},
#   {'text': 'prostate cancer', 'start': 47, 'end': 62, 'concept_id': 'D011471'},
#   {'text': 'cancer', 'start': 56, 'end': 62, 'concept_id': 'D009369'},
#   {'text': 'carcinoma', 'start': 82, 'end': 91, 'concept_id': 'D002277'},
#   {'text': 'cancer', 'start': 116, 'end': 122, 'concept_id': 'D009369'},
#   {'text': 'cancer', 'start': 230, 'end': 236, 'concept_id': 'D009369'},
#   {'text': 'prostate cancer',
#    'start': 387,
#    'end': 402,
#    'concept_id': 'D011471'},
#   {'text': 'cancer', 'start': 396, 'end': 402, 'concept_id': 'D009369'},
#   {'text': 'tumor', 'start': 526, 'end': 531, 'concept_id': 'D009369'},
#   {'text': 'PTEN', 'start': 549, 'end': 553, 'concept_id': 'D006223'},
#   {'text': 'MMAC1', 'start': 554, 'end': 559, 'concept_id': 'D006223'},
#   {'text': 'was', 'start': 561, 'end': 564, 'concept_id': 'D014923'},
#   {'text': 'prostate cancer',
#    'start': 667,
#    'end': 682,
#    'concept_id': 'D011471'},
#   {'text': 'cancer', 'start': 676, 'end': 682, 'concept_id': 'D009369'},
#   {'text': 'tumors', 'start': 719, 'end': 725, 'concept_id': 'D009369'},
#   {'text': 'PTEN', 'start': 862, 'end': 866, 'concept_id': 'D006223'},
#   {'text': 'MMAC1', 'start': 867, 'end': 872, 'concept_id': 'D006223'},
#   {'text': 'tumors', 'start': 1065, 'end': 1071, 'concept_id': 'D009369'},
#   {'text': 'PTEN', 'start': 1084, 'end': 1088, 'concept_id': 'D006223'},
#   {'text': 'MMAC1', 'start': 1089, 'end': 1094, 'concept_id': 'D006223'},
#   {'text': 'prostate cancer',
#    'start': 1149,
#    'end': 1164,
#    'concept_id': 'D011471'},
#   {'text': 'cancer', 'start': 1158, 'end': 1164, 'concept_id': 'D009369'}],
#  '9382108': [{'text': 'Huntington disease',
#    'start': 41,
#    'end': 59,
#    'concept_id': 'D006816'},
#   {'text': 'disease', 'start': 52, 'end': 59, 'concept_id': 'D004194'},
#   {'text': 'Huntington disease',
#    'start': 94,
#    'end': 112,
#    'concept_id': 'D006816'},
#   {'text': 'disease', 'start': 105, 'end': 112, 'concept_id': 'D004194'},
#   {'text': 'was', 'start': 118, 'end': 121, 'concept_id': 'D014923'},
#   {'text': 'included', 'start': 255, 'end': 263, 'concept_id': 'C565249'},
#   {'text': 'included', 'start': 255, 'end': 263, 'concept_id': '609006'},
#   {'text': 'included', 'start': 255, 'end': 263, 'concept_id': 'C566169'},
#   {'text': 'included', 'start': 255, 'end': 263, 'concept_id': 'C566910'},
#   {'text': 'included', 'start': 255, 'end': 263, 'concept_id': 'D029424'},
#   {'text': 'included', 'start': 255, 'end': 263, 'concept_id': '606346'},
#   {'text': 'included', 'start': 255, 'end': 263, 'concept_id': 'C563526'},
#   {'text': 'was', 'start': 592, 'end': 595, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 724, 'end': 727, 'concept_id': 'D014923'},
#   {'text': 'can', 'start': 879, 'end': 882, 'concept_id': 'C567382'}],
#  '9385378': [{'text': 'mucopolysaccharidosis',
#    'start': 96,
#    'end': 117,
#    'concept_id': 'D009083'},
#   {'text': 'IVA', 'start': 118, 'end': 121, 'concept_id': 'C538167'},
#   {'text': 'Mucopolysaccharidosis',
#    'start': 123,
#    'end': 144,
#    'concept_id': 'D009083'},
#   {'text': 'IVA', 'start': 145, 'end': 148, 'concept_id': 'C538167'},
#   {'text': 'MPS IVA', 'start': 150, 'end': 157, 'concept_id': 'D009085'},
#   {'text': 'IVA', 'start': 154, 'end': 157, 'concept_id': 'C538167'},
#   {'text': 'MPS IVA', 'start': 498, 'end': 505, 'concept_id': 'D009085'},
#   {'text': 'IVA', 'start': 502, 'end': 505, 'concept_id': 'C538167'},
#   {'text': 'MPS IVA', 'start': 772, 'end': 779, 'concept_id': 'D009085'},
#   {'text': 'IVA', 'start': 776, 'end': 779, 'concept_id': 'C538167'},
#   {'text': 'all', 'start': 1272, 'end': 1275, 'concept_id': 'D054198'}],
#  '9391879': [{'text': 'ovarian cancer',
#    'start': 62,
#    'end': 76,
#    'concept_id': 'D010051'},
#   {'text': 'cancer', 'start': 70, 'end': 76, 'concept_id': 'D009369'},
#   {'text': 'ovarian cancer',
#    'start': 134,
#    'end': 148,
#    'concept_id': 'D010051'},
#   {'text': 'cancer', 'start': 142, 'end': 148, 'concept_id': 'D009369'},
#   {'text': 'breast cancer', 'start': 247, 'end': 260, 'concept_id': 'D001943'},
#   {'text': 'cancer', 'start': 254, 'end': 260, 'concept_id': 'D009369'},
#   {'text': 'ovarian cancer',
#    'start': 288,
#    'end': 302,
#    'concept_id': 'D010051'},
#   {'text': 'cancer', 'start': 296, 'end': 302, 'concept_id': 'D009369'},
#   {'text': 'was', 'start': 457, 'end': 460, 'concept_id': 'D014923'},
#   {'text': 'disease', 'start': 534, 'end': 541, 'concept_id': 'D004194'},
#   {'text': 'disease', 'start': 573, 'end': 580, 'concept_id': 'D004194'},
#   {'text': 'was', 'start': 636, 'end': 639, 'concept_id': 'D014923'},
#   {'text': 'ovarian cancer',
#    'start': 842,
#    'end': 856,
#    'concept_id': 'D010051'},
#   {'text': 'cancer', 'start': 850, 'end': 856, 'concept_id': 'D009369'}],
#  '9391889': [{'text': 'congenital myotonic dystrophy',
#    'start': 25,
#    'end': 54,
#    'concept_id': 'D009223'},
#   {'text': 'myotonic dystrophy',
#    'start': 36,
#    'end': 54,
#    'concept_id': 'D009223'},
#   {'text': 'congenital myotonic dystrophy',
#    'start': 104,
#    'end': 133,
#    'concept_id': 'D009223'},
#   {'text': 'myotonic dystrophy',
#    'start': 115,
#    'end': 133,
#    'concept_id': 'D009223'},
#   {'text': 'muscular weakness',
#    'start': 212,
#    'end': 229,
#    'concept_id': 'D018908'}],
#  '9400934': [{'text': 'RB1', 'start': 4, 'end': 7, 'concept_id': 'D012175'},
#   {'text': 'retinoblastoma', 'start': 59, 'end': 73, 'concept_id': 'D012175'},
#   {'text': 'RB1', 'start': 79, 'end': 82, 'concept_id': 'D012175'},
#   {'text': 'was', 'start': 97, 'end': 100, 'concept_id': 'D014923'},
#   {'text': 'retinoblastoma',
#    'start': 151,
#    'end': 165,
#    'concept_id': 'D012175'},
#   {'text': 'RB1', 'start': 292, 'end': 295, 'concept_id': 'D012175'},
#   {'text': 'was', 'start': 301, 'end': 304, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 400, 'end': 403, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 542, 'end': 545, 'concept_id': 'D014923'},
#   {'text': 'RB1', 'start': 595, 'end': 598, 'concept_id': 'D012175'},
#   {'text': 'retinoblastoma',
#    'start': 753,
#    'end': 767,
#    'concept_id': 'D012175'}],
#  '941901': [{'text': 'melanoma',
#    'start': 202,
#    'end': 210,
#    'concept_id': 'D008545'},
#   {'text': 'Tay-Sachs disease',
#    'start': 347,
#    'end': 364,
#    'concept_id': 'D013661'},
#   {'text': 'disease', 'start': 357, 'end': 364, 'concept_id': 'D004194'},
#   {'text': 'TSD', 'start': 366, 'end': 369, 'concept_id': 'D013661'},
#   {'text': 'TSD', 'start': 738, 'end': 741, 'concept_id': 'D013661'},
#   {'text': 'TSD', 'start': 972, 'end': 975, 'concept_id': 'D013661'},
#   {'text': 'TSD', 'start': 1114, 'end': 1117, 'concept_id': 'D013661'}],
#  '9420335': [{'text': 'tumor', 'start': 4, 'end': 9, 'concept_id': 'D009369'},
#   {'text': 'tumor', 'start': 150, 'end': 155, 'concept_id': 'D009369'},
#   {'text': 'pancreatic cancers',
#    'start': 254,
#    'end': 272,
#    'concept_id': 'D010190'},
#   {'text': 'cancers', 'start': 265, 'end': 272, 'concept_id': 'D009369'},
#   {'text': 'tetraploid', 'start': 650, 'end': 660, 'concept_id': 'D057891'}],
#  '9425228': [{'text': 'melanoma',
#    'start': 52,
#    'end': 60,
#    'concept_id': 'D008545'},
#   {'text': 'Familial Melanoma',
#    'start': 98,
#    'end': 115,
#    'concept_id': 'D000096142'},
#   {'text': 'Melanoma', 'start': 107, 'end': 115, 'concept_id': 'D008545'},
#   {'text': 'melanoma', 'start': 208, 'end': 216, 'concept_id': 'D008545'},
#   {'text': 'melanoma', 'start': 321, 'end': 329, 'concept_id': 'D008545'},
#   {'text': 'was', 'start': 676, 'end': 679, 'concept_id': 'D014923'},
#   {'text': 'familial melanoma',
#    'start': 949,
#    'end': 966,
#    'concept_id': 'D000096142'},
#   {'text': 'melanoma', 'start': 958, 'end': 966, 'concept_id': 'D008545'},
#   {'text': 'melanoma', 'start': 1010, 'end': 1018, 'concept_id': 'D008545'}],
#  '9425239': [{'text': 'myotonic dystrophy',
#    'start': 77,
#    'end': 95,
#    'concept_id': 'D009223'},
#   {'text': 'myotonic dystrophy',
#    'start': 127,
#    'end': 145,
#    'concept_id': 'D009223'},
#   {'text': 'disease', 'start': 644, 'end': 651, 'concept_id': 'D004194'},
#   {'text': 'myotonic dystrophy',
#    'start': 1053,
#    'end': 1071,
#    'concept_id': 'D009223'}],
#  '9427148': [{'text': 'Aspartylglucosaminuria',
#    'start': 0,
#    'end': 22,
#    'concept_id': 'D054880'},
#   {'text': 'Aspartylglucosaminuria',
#    'start': 48,
#    'end': 70,
#    'concept_id': 'D054880'},
#   {'text': 'AGU', 'start': 72, 'end': 75, 'concept_id': 'D054880'},
#   {'text': 'AGU', 'start': 203, 'end': 206, 'concept_id': 'D054880'},
#   {'text': 'AGU', 'start': 354, 'end': 357, 'concept_id': 'D054880'},
#   {'text': 'all', 'start': 481, 'end': 484, 'concept_id': 'D054198'},
#   {'text': 'AGU', 'start': 559, 'end': 562, 'concept_id': 'D054880'},
#   {'text': 'disease', 'start': 624, 'end': 631, 'concept_id': 'D004194'}],
#  '9439660': [{'text': 'ataxia',
#    'start': 42,
#    'end': 48,
#    'concept_id': 'D001259'},
#   {'text': 'ataxia-telangiectasia',
#    'start': 42,
#    'end': 63,
#    'concept_id': 'D001260'},
#   {'text': 'telangiectasia', 'start': 49, 'end': 63, 'concept_id': 'D013684'},
#   {'text': 'ataxia', 'start': 152, 'end': 158, 'concept_id': 'D001259'},
#   {'text': 'ataxia-telangiectasia',
#    'start': 152,
#    'end': 173,
#    'concept_id': 'D001260'},
#   {'text': 'telangiectasia',
#    'start': 159,
#    'end': 173,
#    'concept_id': 'D013684'},
#   {'text': 'syndrome', 'start': 256, 'end': 264, 'concept_id': 'D013577'},
#   {'text': 'malignancy', 'start': 381, 'end': 391, 'concept_id': 'D009369'},
#   {'text': 'cancer', 'start': 470, 'end': 476, 'concept_id': 'D009369'},
#   {'text': 'can', 'start': 1059, 'end': 1062, 'concept_id': 'C567382'},
#   {'text': 'cancers', 'start': 1221, 'end': 1228, 'concept_id': 'D009369'},
#   {'text': 'tumor', 'start': 1301, 'end': 1306, 'concept_id': 'D009369'}],
#  '9443866': [{'text': 'Ataxia', 'start': 0, 'end': 6, 'concept_id': 'D001259'},
#   {'text': 'Ataxia-telangiectasia',
#    'start': 0,
#    'end': 21,
#    'concept_id': 'D001260'},
#   {'text': 'telangiectasia', 'start': 7, 'end': 21, 'concept_id': 'D013684'},
#   {'text': 'diseases', 'start': 197, 'end': 205, 'concept_id': 'D004194'},
#   {'text': 'diseases', 'start': 197, 'end': 205, 'concept_id': 'C'},
#   {'text': 'breast cancer', 'start': 215, 'end': 228, 'concept_id': 'D001943'},
#   {'text': 'cancer', 'start': 222, 'end': 228, 'concept_id': 'D009369'},
#   {'text': 'ataxia', 'start': 309, 'end': 315, 'concept_id': 'D001259'},
#   {'text': 'ataxia-telangiectasia',
#    'start': 309,
#    'end': 330,
#    'concept_id': 'D001260'},
#   {'text': 'telangiectasia',
#    'start': 316,
#    'end': 330,
#    'concept_id': 'D013684'},
#   {'text': 'all', 'start': 642, 'end': 645, 'concept_id': 'D054198'}],
#  '9448273': [{'text': 'tumor',
#    'start': 22,
#    'end': 27,
#    'concept_id': 'D009369'},
#   {'text': 'tumor', 'start': 147, 'end': 152, 'concept_id': 'D009369'},
#   {'text': 'cancer', 'start': 219, 'end': 225, 'concept_id': 'D009369'},
#   {'text': 'syndrome', 'start': 226, 'end': 234, 'concept_id': 'D013577'},
#   {'text': 'renal cell carcinomas',
#    'start': 267,
#    'end': 288,
#    'concept_id': 'D002292'},
#   {'text': 'carcinomas', 'start': 278, 'end': 288, 'concept_id': 'D002277'},
#   {'text': 'RCC', 'start': 290, 'end': 293, 'concept_id': 'D002292'},
#   {'text': 'hemangioblastomas',
#    'start': 305,
#    'end': 322,
#    'concept_id': 'D018325'},
#   {'text': 'RCC', 'start': 343, 'end': 346, 'concept_id': 'D002292'},
#   {'text': 'cancer', 'start': 571, 'end': 577, 'concept_id': 'D009369'},
#   {'text': 'RCC', 'start': 738, 'end': 741, 'concept_id': 'D002292'},
#   {'text': 'cancer', 'start': 742, 'end': 748, 'concept_id': 'D009369'},
#   {'text': 'RCC', 'start': 851, 'end': 854, 'concept_id': 'D002292'},
#   {'text': 'tumor', 'start': 1200, 'end': 1205, 'concept_id': 'D009369'},
#   {'text': 'tumor', 'start': 1304, 'end': 1309, 'concept_id': 'D009369'}],
#  '9450866': [{'text': 'Piebaldism',
#    'start': 0,
#    'end': 10,
#    'concept_id': 'D016116'},
#   {'text': 'deafness', 'start': 16, 'end': 24, 'concept_id': 'D003638'},
#   {'text': 'syndrome', 'start': 61, 'end': 69, 'concept_id': 'D013577'},
#   {'text': 'piebaldism', 'start': 122, 'end': 132, 'concept_id': 'D016116'},
#   {'text': 'deafness', 'start': 171, 'end': 179, 'concept_id': 'D003638'},
#   {'text': 'spotting', 'start': 396, 'end': 404, 'concept_id': 'D008796'},
#   {'text': 'deafness', 'start': 431, 'end': 439, 'concept_id': 'D003638'},
#   {'text': 'piebaldism', 'start': 464, 'end': 474, 'concept_id': 'D016116'},
#   {'text': 'deafness', 'start': 514, 'end': 522, 'concept_id': 'D003638'},
#   {'text': 'piebaldism', 'start': 584, 'end': 594, 'concept_id': 'D016116'},
#   {'text': 'piebaldism', 'start': 675, 'end': 685, 'concept_id': 'D016116'},
#   {'text': 'Waardenburg syndrome',
#    'start': 711,
#    'end': 731,
#    'concept_id': 'D014849'},
#   {'text': 'syndrome', 'start': 723, 'end': 731, 'concept_id': 'D013577'}],
#  '9457913': [{'text': 'epidermolysis bullosa',
#    'start': 170,
#    'end': 191,
#    'concept_id': 'D004820'},
#   {'text': 'epidermolysis bullosa',
#    'start': 235,
#    'end': 256,
#    'concept_id': 'D004820'},
#   {'text': 'epidermolysis bullosa',
#    'start': 479,
#    'end': 500,
#    'concept_id': 'D004820'},
#   {'text': 'was', 'start': 1278, 'end': 1281, 'concept_id': 'D014923'},
#   {'text': 'can', 'start': 1812, 'end': 1815, 'concept_id': 'C567382'},
#   {'text': 'can', 'start': 1931, 'end': 1934, 'concept_id': 'C567382'}],
#  '9457914': [{'text': 'epidermolysis bullosa',
#    'start': 90,
#    'end': 111,
#    'concept_id': 'D004820'},
#   {'text': 'epidermolysis bullosa',
#    'start': 201,
#    'end': 222,
#    'concept_id': 'D004820'},
#   {'text': 'junctional epidermolysis bullosa',
#    'start': 252,
#    'end': 284,
#    'concept_id': 'D016109'},
#   {'text': 'epidermolysis bullosa',
#    'start': 263,
#    'end': 284,
#    'concept_id': 'D004820'},
#   {'text': 'patchy alopecia',
#    'start': 331,
#    'end': 346,
#    'concept_id': 'C531609'},
#   {'text': 'alopecia', 'start': 338, 'end': 346, 'concept_id': 'D000505'},
#   {'text': 'epidermolysis bullosa',
#    'start': 552,
#    'end': 573,
#    'concept_id': 'D004820'},
#   {'text': 'was', 'start': 1071, 'end': 1074, 'concept_id': 'D014923'},
#   {'text': 'Eco', 'start': 1130, 'end': 1133, 'concept_id': 'C567210'},
#   {'text': 'All', 'start': 1141, 'end': 1144, 'concept_id': 'D054198'}],
#  '9463309': [{'text': 'was',
#    'start': 474,
#    'end': 477,
#    'concept_id': 'D014923'},
#   {'text': 'was', 'start': 538, 'end': 541, 'concept_id': 'D014923'},
#   {'text': 'included', 'start': 542, 'end': 550, 'concept_id': 'C565249'},
#   {'text': 'included', 'start': 542, 'end': 550, 'concept_id': '609006'},
#   {'text': 'included', 'start': 542, 'end': 550, 'concept_id': 'C566169'},
#   {'text': 'included', 'start': 542, 'end': 550, 'concept_id': 'C566910'},
#   {'text': 'included', 'start': 542, 'end': 550, 'concept_id': 'D029424'},
#   {'text': 'included', 'start': 542, 'end': 550, 'concept_id': '606346'},
#   {'text': 'included', 'start': 542, 'end': 550, 'concept_id': 'C563526'},
#   {'text': 'Hp2', 'start': 784, 'end': 787, 'concept_id': 'C536415'},
#   {'text': 'Hp2', 'start': 900, 'end': 903, 'concept_id': 'C536415'},
#   {'text': 'Hp2', 'start': 909, 'end': 912, 'concept_id': 'C536415'},
#   {'text': 'Hp2', 'start': 937, 'end': 940, 'concept_id': 'C536415'},
#   {'text': 'Hp1', 'start': 947, 'end': 950, 'concept_id': 'C536414'},
#   {'text': 'Hp2', 'start': 951, 'end': 954, 'concept_id': 'C536415'},
#   {'text': 'Hp2', 'start': 1007, 'end': 1010, 'concept_id': 'C536415'},
#   {'text': 'Hp2', 'start': 1016, 'end': 1019, 'concept_id': 'C536415'},
#   {'text': 'Hp1', 'start': 1053, 'end': 1056, 'concept_id': 'C536414'},
#   {'text': 'Hp1', 'start': 1061, 'end': 1064, 'concept_id': 'C536414'},
#   {'text': 'Hp1', 'start': 1140, 'end': 1143, 'concept_id': 'C536414'},
#   {'text': 'Hp2', 'start': 1149, 'end': 1152, 'concept_id': 'C536415'},
#   {'text': 'Hp2', 'start': 1350, 'end': 1353, 'concept_id': 'C536415'},
#   {'text': 'Hp1', 'start': 1404, 'end': 1407, 'concept_id': 'C536414'},
#   {'text': 'was', 'start': 1414, 'end': 1417, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 1437, 'end': 1440, 'concept_id': 'D014923'},
#   {'text': 'Hp1', 'start': 1501, 'end': 1504, 'concept_id': 'C536414'},
#   {'text': 'Hp2', 'start': 1594, 'end': 1597, 'concept_id': 'C536415'},
#   {'text': 'Hp2', 'start': 1619, 'end': 1622, 'concept_id': 'C536415'},
#   {'text': 'was', 'start': 1629, 'end': 1632, 'concept_id': 'D014923'},
#   {'text': 'all', 'start': 1651, 'end': 1654, 'concept_id': 'D054198'}],
#  '9463314': [{'text': 'ataxia',
#    'start': 32,
#    'end': 38,
#    'concept_id': 'D001259'},
#   {'text': 'ataxia-telangiectasia',
#    'start': 32,
#    'end': 53,
#    'concept_id': 'D001260'},
#   {'text': 'telangiectasia', 'start': 39, 'end': 53, 'concept_id': 'D013684'},
#   {'text': 'leukemia', 'start': 126, 'end': 134, 'concept_id': 'D007938'},
#   {'text': 'lymphoma', 'start': 136, 'end': 144, 'concept_id': 'D008223'},
#   {'text': 'breast cancer', 'start': 150, 'end': 163, 'concept_id': 'D001943'},
#   {'text': 'cancer', 'start': 157, 'end': 163, 'concept_id': 'D009369'},
#   {'text': 'ataxia', 'start': 220, 'end': 226, 'concept_id': 'D001259'},
#   {'text': 'ataxia-telangiectasia',
#    'start': 220,
#    'end': 241,
#    'concept_id': 'D001260'},
#   {'text': 'telangiectasia',
#    'start': 227,
#    'end': 241,
#    'concept_id': 'D013684'},
#   {'text': 'breast cancer', 'start': 613, 'end': 626, 'concept_id': 'D001943'},
#   {'text': 'cancer', 'start': 620, 'end': 626, 'concept_id': 'D009369'},
#   {'text': 'leukemia', 'start': 1009, 'end': 1017, 'concept_id': 'D007938'},
#   {'text': 'lymphoma', 'start': 1019, 'end': 1027, 'concept_id': 'D008223'},
#   {'text': 'Hodgkin lymphoma',
#    'start': 1066,
#    'end': 1082,
#    'concept_id': 'D006689'},
#   {'text': 'lymphoma', 'start': 1074, 'end': 1082, 'concept_id': 'D008223'},
#   {'text': 'all', 'start': 1250, 'end': 1253, 'concept_id': 'D054198'}],
#  '9463318': [{'text': 'myotonic dystrophy',
#    'start': 35,
#    'end': 53,
#    'concept_id': 'D009223'},
#   {'text': 'myotonic dystrophy',
#    'start': 318,
#    'end': 336,
#    'concept_id': 'D009223'},
#   {'text': 'all', 'start': 645, 'end': 648, 'concept_id': 'D054198'},
#   {'text': 'was', 'start': 886, 'end': 889, 'concept_id': 'D014923'},
#   {'text': 'disease', 'start': 963, 'end': 970, 'concept_id': 'D004194'},
#   {'text': 'was', 'start': 971, 'end': 974, 'concept_id': 'D014923'}],
#  '9465039': [{'text': 'hemochromatosis',
#    'start': 4,
#    'end': 19,
#    'concept_id': 'D006432'},
#   {'text': 'hemochromatosis', 'start': 4, 'end': 19, 'concept_id': 'D006432'},
#   {'text': 'hemochromatosis',
#    'start': 196,
#    'end': 211,
#    'concept_id': 'D006432'},
#   {'text': 'hemochromatosis',
#    'start': 196,
#    'end': 211,
#    'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 219, 'end': 222, 'concept_id': 'D006432'},
#   {'text': 'was', 'start': 312, 'end': 315, 'concept_id': 'D014923'},
#   {'text': 'HFE', 'start': 439, 'end': 442, 'concept_id': 'D006432'},
#   {'text': 'was', 'start': 594, 'end': 597, 'concept_id': 'D014923'},
#   {'text': 'HFE', 'start': 757, 'end': 760, 'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 803, 'end': 806, 'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 951, 'end': 954, 'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 1073, 'end': 1076, 'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 1311, 'end': 1314, 'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 1542, 'end': 1545, 'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 1814, 'end': 1817, 'concept_id': 'D006432'},
#   {'text': 'hemochromatosis',
#    'start': 1995,
#    'end': 2010,
#    'concept_id': 'D006432'},
#   {'text': 'hemochromatosis',
#    'start': 1995,
#    'end': 2010,
#    'concept_id': 'D006432'}],
#  '9465301': [{'text': 'Angelman syndrome',
#    'start': 173,
#    'end': 190,
#    'concept_id': 'D017204'},
#   {'text': 'syndrome', 'start': 182, 'end': 190, 'concept_id': 'D013577'},
#   {'text': 'uniparental disomy',
#    'start': 255,
#    'end': 273,
#    'concept_id': 'D024182'}],
#  '9467011': [{'text': 'Cowden disease',
#    'start': 53,
#    'end': 67,
#    'concept_id': 'D006223'},
#   {'text': 'disease', 'start': 60, 'end': 67, 'concept_id': 'D004194'},
#   {'text': 'Bannayan-Zonana syndrome',
#    'start': 72,
#    'end': 96,
#    'concept_id': 'D006223'},
#   {'text': 'syndrome', 'start': 88, 'end': 96, 'concept_id': 'D013577'},
#   {'text': 'hamartoma', 'start': 102, 'end': 111, 'concept_id': 'D006222'},
#   {'text': 'syndromes', 'start': 112, 'end': 121, 'concept_id': 'D013577'},
#   {'text': 'PTEN', 'start': 136, 'end': 140, 'concept_id': 'D006223'},
#   {'text': 'PTEN', 'start': 178, 'end': 182, 'concept_id': 'D006223'},
#   {'text': 'was', 'start': 305, 'end': 308, 'concept_id': 'D014923'},
#   {'text': 'malignancy', 'start': 354, 'end': 364, 'concept_id': 'D009369'},
#   {'text': 'PTEN', 'start': 374, 'end': 378, 'concept_id': 'D006223'},
#   {'text': 'kidney cancer', 'start': 457, 'end': 470, 'concept_id': 'D007680'},
#   {'text': 'cancer', 'start': 464, 'end': 470, 'concept_id': 'D009369'},
#   {'text': 'endometrial carcinomas',
#    'start': 521,
#    'end': 543,
#    'concept_id': 'D016889'},
#   {'text': 'carcinomas', 'start': 533, 'end': 543, 'concept_id': 'D002277'},
#   {'text': 'malignant melanoma',
#    'start': 545,
#    'end': 563,
#    'concept_id': 'D008545'},
#   {'text': 'melanoma', 'start': 555, 'end': 563, 'concept_id': 'D008545'},
#   {'text': 'PTEN', 'start': 598, 'end': 602, 'concept_id': 'D006223'},
#   {'text': 'was', 'start': 603, 'end': 606, 'concept_id': 'D014923'},
#   {'text': 'hamartoma', 'start': 653, 'end': 662, 'concept_id': 'D006222'},
#   {'text': 'syndromes', 'start': 663, 'end': 672, 'concept_id': 'D013577'},
#   {'text': 'Cowden disease',
#    'start': 674,
#    'end': 688,
#    'concept_id': 'D006223'},
#   {'text': 'disease', 'start': 681, 'end': 688, 'concept_id': 'D004194'},
#   {'text': 'BZS', 'start': 727, 'end': 730, 'concept_id': 'D006223'},
#   {'text': 'Riley-Smith syndrome',
#    'start': 745,
#    'end': 765,
#    'concept_id': 'D006223'},
#   {'text': 'syndrome', 'start': 757, 'end': 765, 'concept_id': 'D013577'},
#   {'text': 'BZS', 'start': 827, 'end': 830, 'concept_id': 'D006223'},
#   {'text': 'was', 'start': 840, 'end': 843, 'concept_id': 'D014923'},
#   {'text': 'PTEN', 'start': 866, 'end': 870, 'concept_id': 'D006223'},
#   {'text': 'PTEN', 'start': 882, 'end': 886, 'concept_id': 'D006223'},
#   {'text': 'PTEN', 'start': 1121, 'end': 1125, 'concept_id': 'D006223'},
#   {'text': 'PTEN', 'start': 1198, 'end': 1202, 'concept_id': 'D006223'},
#   {'text': 'was', 'start': 1218, 'end': 1221, 'concept_id': 'D014923'},
#   {'text': 'PTEN', 'start': 1521, 'end': 1525, 'concept_id': 'D006223'},
#   {'text': 'BZS', 'start': 1575, 'end': 1578, 'concept_id': 'D006223'},
#   {'text': 'was', 'start': 1636, 'end': 1639, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 1747, 'end': 1750, 'concept_id': 'D014923'},
#   {'text': 'BZS', 'start': 1819, 'end': 1822, 'concept_id': 'D006223'},
#   {'text': 'BZS', 'start': 1900, 'end': 1903, 'concept_id': 'D006223'},
#   {'text': 'was', 'start': 2068, 'end': 2071, 'concept_id': 'D014923'},
#   {'text': 'breast disease',
#    'start': 2126,
#    'end': 2140,
#    'concept_id': 'D001941'},
#   {'text': 'disease', 'start': 2133, 'end': 2140, 'concept_id': 'D004194'},
#   {'text': 'was', 'start': 2156, 'end': 2159, 'concept_id': 'D014923'},
#   {'text': 'PTEN', 'start': 2203, 'end': 2207, 'concept_id': 'D006223'},
#   {'text': 'was', 'start': 2344, 'end': 2347, 'concept_id': 'D014923'},
#   {'text': 'PTEN', 'start': 2388, 'end': 2392, 'concept_id': 'D006223'},
#   {'text': 'breast disease',
#    'start': 2416,
#    'end': 2430,
#    'concept_id': 'D001941'},
#   {'text': 'disease', 'start': 2423, 'end': 2430, 'concept_id': 'D004194'},
#   {'text': 'all', 'start': 2639, 'end': 2642, 'concept_id': 'D054198'}],
#  '9472666': [{'text': 'C6 deficiency',
#    'start': 56,
#    'end': 69,
#    'concept_id': 'C567307'},
#   {'text': 'C6 deficiency', 'start': 122, 'end': 135, 'concept_id': 'C567307'},
#   {'text': 'C6D', 'start': 137, 'end': 140, 'concept_id': 'C567307'},
#   {'text': 'was', 'start': 142, 'end': 145, 'concept_id': 'D014923'},
#   {'text': 'meningococcal meningitis',
#    'start': 200,
#    'end': 224,
#    'concept_id': 'D008585'},
#   {'text': 'meningitis', 'start': 214, 'end': 224, 'concept_id': 'D008581'},
#   {'text': 'C6D', 'start': 272, 'end': 275, 'concept_id': 'C567307'},
#   {'text': 'meningitis', 'start': 300, 'end': 310, 'concept_id': 'D008581'},
#   {'text': 'infection', 'start': 331, 'end': 340, 'concept_id': 'D007239'},
#   {'text': 'was', 'start': 531, 'end': 534, 'concept_id': 'D014923'},
#   {'text': 'C6D', 'start': 720, 'end': 723, 'concept_id': 'C567307'}],
#  '9482572': [{'text': 'aniridia',
#    'start': 69,
#    'end': 77,
#    'concept_id': 'D015783'},
#   {'text': 'Peters anomaly',
#    'start': 120,
#    'end': 134,
#    'concept_id': 'C537884'},
#   {'text': 'cataracts', 'start': 152, 'end': 161, 'concept_id': 'D002386'},
#   {'text': 'autosomal dominant',
#    'start': 168,
#    'end': 186,
#    'concept_id': 'C566739'},
#   {'text': 'keratitis', 'start': 187, 'end': 196, 'concept_id': 'D007634'},
#   {'text': 'aniridia', 'start': 295, 'end': 303, 'concept_id': 'D015783'},
#   {'text': 'all', 'start': 756, 'end': 759, 'concept_id': 'D054198'}],
#  '9497246': [{'text': 'breast cancer',
#    'start': 78,
#    'end': 91,
#    'concept_id': 'D001943'},
#   {'text': 'cancer', 'start': 85, 'end': 91, 'concept_id': 'D009369'},
#   {'text': 'Breast Cancer', 'start': 106, 'end': 119, 'concept_id': 'D001943'},
#   {'text': 'Cancer', 'start': 113, 'end': 119, 'concept_id': 'D009369'},
#   {'text': 'breast cancer', 'start': 189, 'end': 202, 'concept_id': 'D001943'},
#   {'text': 'cancer', 'start': 196, 'end': 202, 'concept_id': 'D009369'},
#   {'text': 'was', 'start': 203, 'end': 206, 'concept_id': 'D014923'},
#   {'text': 'breast cancer', 'start': 299, 'end': 312, 'concept_id': 'D001943'},
#   {'text': 'cancer', 'start': 306, 'end': 312, 'concept_id': 'D009369'},
#   {'text': 'Breast Cancer', 'start': 331, 'end': 344, 'concept_id': 'D001943'},
#   {'text': 'Cancer', 'start': 338, 'end': 344, 'concept_id': 'D009369'},
#   {'text': 'included', 'start': 379, 'end': 387, 'concept_id': 'C565249'},
#   {'text': 'included', 'start': 379, 'end': 387, 'concept_id': '609006'},
#   {'text': 'included', 'start': 379, 'end': 387, 'concept_id': 'C566169'},
#   {'text': 'included', 'start': 379, 'end': 387, 'concept_id': 'C566910'},
#   {'text': 'included', 'start': 379, 'end': 387, 'concept_id': 'D029424'},
#   {'text': 'included', 'start': 379, 'end': 387, 'concept_id': '606346'},
#   {'text': 'included', 'start': 379, 'end': 387, 'concept_id': 'C563526'},
#   {'text': 'cancers', 'start': 441, 'end': 448, 'concept_id': 'D009369'},
#   {'text': 'disease', 'start': 459, 'end': 466, 'concept_id': 'D004194'},
#   {'text': 'was', 'start': 467, 'end': 470, 'concept_id': 'D014923'},
#   {'text': 'ovarian cancer',
#    'start': 688,
#    'end': 702,
#    'concept_id': 'D010051'},
#   {'text': 'cancer', 'start': 696, 'end': 702, 'concept_id': 'D009369'},
#   {'text': 'breast cancer', 'start': 826, 'end': 839, 'concept_id': 'D001943'},
#   {'text': 'cancer', 'start': 833, 'end': 839, 'concept_id': 'D009369'},
#   {'text': 'was', 'start': 925, 'end': 928, 'concept_id': 'D014923'},
#   {'text': 'breast cancer', 'start': 981, 'end': 994, 'concept_id': 'D001943'},
#   {'text': 'cancer', 'start': 988, 'end': 994, 'concept_id': 'D009369'},
#   {'text': 'disease', 'start': 1183, 'end': 1190, 'concept_id': 'D004194'},
#   {'text': 'was', 'start': 1391, 'end': 1394, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 1473, 'end': 1476, 'concept_id': 'D014923'},
#   {'text': 'all', 'start': 1548, 'end': 1551, 'concept_id': 'D054198'},
#   {'text': 'breast cancer',
#    'start': 1616,
#    'end': 1629,
#    'concept_id': 'D001943'},
#   {'text': 'cancer', 'start': 1623, 'end': 1629, 'concept_id': 'D009369'},
#   {'text': 'ovarian cancer',
#    'start': 1736,
#    'end': 1750,
#    'concept_id': 'D010051'},
#   {'text': 'cancer', 'start': 1744, 'end': 1750, 'concept_id': 'D009369'},
#   {'text': 'breast cancer',
#    'start': 1863,
#    'end': 1876,
#    'concept_id': 'D001943'},
#   {'text': 'cancer', 'start': 1870, 'end': 1876, 'concept_id': 'D009369'},
#   {'text': 'was', 'start': 1934, 'end': 1937, 'concept_id': 'D014923'}],
#  '9506545': [{'text': 'autosomal dominant',
#    'start': 54,
#    'end': 72,
#    'concept_id': 'C566739'},
#   {'text': 'cerebellar ataxia',
#    'start': 73,
#    'end': 90,
#    'concept_id': 'D002524'},
#   {'text': 'ataxia', 'start': 84, 'end': 90, 'concept_id': 'D001259'},
#   {'text': 'autosomal dominant',
#    'start': 259,
#    'end': 277,
#    'concept_id': 'C566739'},
#   {'text': 'cerebellar ataxias',
#    'start': 278,
#    'end': 296,
#    'concept_id': 'D002524'},
#   {'text': 'ataxias', 'start': 289, 'end': 296, 'concept_id': 'D001259'},
#   {'text': 'spinocerebellar ataxias',
#    'start': 304,
#    'end': 327,
#    'concept_id': 'D020754'},
#   {'text': 'ataxias', 'start': 320, 'end': 327, 'concept_id': 'D001259'},
#   {'text': 'SCA1', 'start': 337, 'end': 341, 'concept_id': 'D020754'},
#   {'text': 'SCA2', 'start': 351, 'end': 355, 'concept_id': 'D020754'},
#   {'text': 'SCA3', 'start': 369, 'end': 373, 'concept_id': 'D017827'},
#   {'text': 'Machado-Joseph disease',
#    'start': 374,
#    'end': 396,
#    'concept_id': 'D017827'},
#   {'text': 'Joseph disease',
#    'start': 382,
#    'end': 396,
#    'concept_id': 'D017827'},
#   {'text': 'disease', 'start': 389, 'end': 396, 'concept_id': 'D004194'},
#   {'text': 'MJD', 'start': 398, 'end': 401, 'concept_id': 'D017827'},
#   {'text': 'SCA1', 'start': 416, 'end': 420, 'concept_id': 'D020754'},
#   {'text': 'was', 'start': 440, 'end': 443, 'concept_id': 'D014923'},
#   {'text': 'hypermetria', 'start': 482, 'end': 493, 'concept_id': 'D002524'},
#   {'text': 'was', 'start': 519, 'end': 522, 'concept_id': 'D014923'},
#   {'text': 'SCA2', 'start': 537, 'end': 541, 'concept_id': 'D020754'},
#   {'text': 'was', 'start': 560, 'end': 563, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 625, 'end': 628, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 651, 'end': 654, 'concept_id': 'D014923'},
#   {'text': 'disease', 'start': 692, 'end': 699, 'concept_id': 'D004194'},
#   {'text': 'was', 'start': 802, 'end': 805, 'concept_id': 'D014923'},
#   {'text': 'SCA3', 'start': 816, 'end': 820, 'concept_id': 'D017827'},
#   {'text': 'was', 'start': 844, 'end': 847, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 865, 'end': 868, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 912, 'end': 915, 'concept_id': 'D014923'},
#   {'text': 'SCA1', 'start': 1081, 'end': 1085, 'concept_id': 'D020754'},
#   {'text': 'SCA2', 'start': 1098, 'end': 1102, 'concept_id': 'D020754'},
#   {'text': 'SCA3', 'start': 1133, 'end': 1137, 'concept_id': 'D017827'},
#   {'text': 'SCA1', 'start': 1228, 'end': 1232, 'concept_id': 'D020754'},
#   {'text': 'SCA2', 'start': 1234, 'end': 1238, 'concept_id': 'D020754'},
#   {'text': 'SCA3', 'start': 1244, 'end': 1248, 'concept_id': 'D017827'},
#   {'text': 'diseases', 'start': 1281, 'end': 1289, 'concept_id': 'D004194'},
#   {'text': 'diseases', 'start': 1281, 'end': 1289, 'concept_id': 'C'}],
#  '9521325': [{'text': 'idiopathic ventricular fibrillation',
#    'start': 42,
#    'end': 77,
#    'concept_id': 'C537182'},
#   {'text': 'ventricular fibrillation',
#    'start': 53,
#    'end': 77,
#    'concept_id': 'D014693'},
#   {'text': 'Ventricular fibrillation',
#    'start': 79,
#    'end': 103,
#    'concept_id': 'D014693'},
#   {'text': 'idiopathic ventricular fibrillation',
#    'start': 328,
#    'end': 363,
#    'concept_id': 'C537182'},
#   {'text': 'ventricular fibrillation',
#    'start': 339,
#    'end': 363,
#    'concept_id': 'D014693'},
#   {'text': 'sudden death', 'start': 552, 'end': 564, 'concept_id': 'D003645'},
#   {'text': 'death', 'start': 559, 'end': 564, 'concept_id': 'D003643'},
#   {'text': 'SCN5', 'start': 813, 'end': 817, 'concept_id': '615285'},
#   {'text': 'SCN5', 'start': 939, 'end': 943, 'concept_id': '615285'}],
#  '9521421': [{'text': 'mucopolysaccharidosis',
#    'start': 27,
#    'end': 48,
#    'concept_id': 'D009083'},
#   {'text': 'IVA', 'start': 49, 'end': 52, 'concept_id': 'C538167'},
#   {'text': 'Mucopolysaccharidosis',
#    'start': 173,
#    'end': 194,
#    'concept_id': 'D009083'},
#   {'text': 'IVA', 'start': 195, 'end': 198, 'concept_id': 'C538167'},
#   {'text': 'MPS IVA', 'start': 200, 'end': 207, 'concept_id': 'D009085'},
#   {'text': 'IVA', 'start': 204, 'end': 207, 'concept_id': 'C538167'},
#   {'text': 'MPS IVA', 'start': 476, 'end': 483, 'concept_id': 'D009085'},
#   {'text': 'IVA', 'start': 480, 'end': 483, 'concept_id': 'C538167'},
#   {'text': 'MPS IVA', 'start': 593, 'end': 600, 'concept_id': 'D009085'},
#   {'text': 'IVA', 'start': 597, 'end': 600, 'concept_id': 'C538167'},
#   {'text': 'MPS IVA', 'start': 1889, 'end': 1896, 'concept_id': 'D009085'},
#   {'text': 'IVA', 'start': 1893, 'end': 1896, 'concept_id': 'C538167'}],
#  '9529364': [{'text': 'WT1', 'start': 33, 'end': 36, 'concept_id': 'D009396'},
#   {'text': 'isolated diffuse mesangial sclerosis',
#    'start': 65,
#    'end': 101,
#    'concept_id': 'C537346'},
#   {'text': 'diffuse mesangial sclerosis',
#    'start': 74,
#    'end': 101,
#    'concept_id': 'C537346'},
#   {'text': 'sclerosis', 'start': 92, 'end': 101, 'concept_id': 'D012598'},
#   {'text': 'WT1', 'start': 227, 'end': 230, 'concept_id': 'D009396'},
#   {'text': 'Denys-Drash syndrome',
#    'start': 356,
#    'end': 376,
#    'concept_id': 'D030321'},
#   {'text': 'Drash syndrome',
#    'start': 362,
#    'end': 376,
#    'concept_id': 'D030321'},
#   {'text': 'syndrome', 'start': 368, 'end': 376, 'concept_id': 'D013577'},
#   {'text': 'DDS', 'start': 378, 'end': 381, 'concept_id': 'D030321'},
#   {'text': 'diffuse mesangial sclerosis',
#    'start': 387,
#    'end': 414,
#    'concept_id': 'C537346'},
#   {'text': 'sclerosis', 'start': 405, 'end': 414, 'concept_id': 'D012598'},
#   {'text': 'pseudohermaphroditism',
#    'start': 437,
#    'end': 458,
#    'concept_id': 'D012734'},
#   {'text': 'Wilms tumor', 'start': 466, 'end': 477, 'concept_id': 'D009396'},
#   {'text': 'tumor', 'start': 472, 'end': 477, 'concept_id': 'D009369'},
#   {'text': 'DDS', 'start': 502, 'end': 505, 'concept_id': 'D030321'},
#   {'text': 'DDS', 'start': 704, 'end': 707, 'concept_id': 'D030321'},
#   {'text': 'urogenital abnormalities',
#    'start': 720,
#    'end': 744,
#    'concept_id': 'D014564'},
#   {'text': 'WT1', 'start': 766, 'end': 769, 'concept_id': 'D009396'},
#   {'text': 'WT1', 'start': 883, 'end': 886, 'concept_id': 'D009396'},
#   {'text': 'DDS', 'start': 996, 'end': 999, 'concept_id': 'D030321'},
#   {'text': 'WT1', 'start': 1013, 'end': 1016, 'concept_id': 'D009396'},
#   {'text': 'disease', 'start': 1114, 'end': 1121, 'concept_id': 'D004194'},
#   {'text': 'WT1', 'start': 1206, 'end': 1209, 'concept_id': 'D009396'}],
#  '9536083': [{'text': 'ovarian cancer',
#    'start': 208,
#    'end': 222,
#    'concept_id': 'D010051'},
#   {'text': 'cancer', 'start': 216, 'end': 222, 'concept_id': 'D009369'},
#   {'text': 'All', 'start': 254, 'end': 257, 'concept_id': 'D054198'},
#   {'text': 'was', 'start': 749, 'end': 752, 'concept_id': 'D014923'},
#   {'text': 'ovarian cancer',
#    'start': 936,
#    'end': 950,
#    'concept_id': 'D010051'},
#   {'text': 'cancer', 'start': 944, 'end': 950, 'concept_id': 'D009369'}],
#  '9546397': [{'text': 'hemochromatosis',
#    'start': 25,
#    'end': 40,
#    'concept_id': 'D006432'},
#   {'text': 'hemochromatosis', 'start': 25, 'end': 40, 'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 49, 'end': 52, 'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 120, 'end': 123, 'concept_id': 'D006432'},
#   {'text': 'iron-overload', 'start': 173, 'end': 186, 'concept_id': 'D019190'},
#   {'text': 'disease', 'start': 187, 'end': 194, 'concept_id': 'D004194'},
#   {'text': 'disease hereditary',
#    'start': 187,
#    'end': 205,
#    'concept_id': 'D030342'},
#   {'text': 'hemochromatosis',
#    'start': 206,
#    'end': 221,
#    'concept_id': 'D006432'},
#   {'text': 'hemochromatosis',
#    'start': 206,
#    'end': 221,
#    'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 223, 'end': 226, 'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 329, 'end': 332, 'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 385, 'end': 388, 'concept_id': 'D006432'},
#   {'text': 'hemochromatosis',
#    'start': 414,
#    'end': 429,
#    'concept_id': 'D006432'},
#   {'text': 'hemochromatosis',
#    'start': 414,
#    'end': 429,
#    'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 560, 'end': 563, 'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 671, 'end': 674, 'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 789, 'end': 792, 'concept_id': 'D006432'},
#   {'text': 'HFE', 'start': 856, 'end': 859, 'concept_id': 'D006432'}],
#  '9554743': [{'text': 'Wilson disease',
#    'start': 111,
#    'end': 125,
#    'concept_id': 'D006527'},
#   {'text': 'disease', 'start': 118, 'end': 125, 'concept_id': 'D004194'},
#   {'text': 'Wilson disease',
#    'start': 277,
#    'end': 291,
#    'concept_id': 'D006527'},
#   {'text': 'disease', 'start': 284, 'end': 291, 'concept_id': 'D004194'},
#   {'text': 'was', 'start': 358, 'end': 361, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 559, 'end': 562, 'concept_id': 'D014923'},
#   {'text': 'Wilson disease',
#    'start': 748,
#    'end': 762,
#    'concept_id': 'D006527'},
#   {'text': 'disease', 'start': 755, 'end': 762, 'concept_id': 'D004194'}],
#  '9563950': [{'text': 'myotonic dystrophy',
#    'start': 61,
#    'end': 79,
#    'concept_id': 'D009223'},
#   {'text': 'Myotonic dystrophy',
#    'start': 81,
#    'end': 99,
#    'concept_id': 'D009223'},
#   {'text': 'was', 'start': 524, 'end': 527, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 655, 'end': 658, 'concept_id': 'D014923'}],
#  '9580132': [{'text': 'neurohypophyseal diabetes insipidus',
#    'start': 149,
#    'end': 184,
#    'concept_id': 'D020790'},
#   {'text': 'diabetes insipidus',
#    'start': 166,
#    'end': 184,
#    'concept_id': 'D003919'},
#   {'text': 'neurohypophyseal diabetes insipidus',
#    'start': 195,
#    'end': 230,
#    'concept_id': 'D020790'},
#   {'text': 'diabetes insipidus',
#    'start': 212,
#    'end': 230,
#    'concept_id': 'D003919'},
#   {'text': 'autosomal dominant',
#    'start': 244,
#    'end': 262,
#    'concept_id': 'C566739'},
#   {'text': 'disease', 'start': 263, 'end': 270, 'concept_id': 'D004194'},
#   {'text': 'was', 'start': 1060, 'end': 1063, 'concept_id': 'D014923'},
#   {'text': 'all', 'start': 1076, 'end': 1079, 'concept_id': 'D054198'}],
#  '9585583': [{'text': 'Saethre-Chotzen syndrome',
#    'start': 25,
#    'end': 49,
#    'concept_id': 'D000168'},
#   {'text': 'Chotzen syndrome',
#    'start': 33,
#    'end': 49,
#    'concept_id': 'D000168'},
#   {'text': 'syndrome', 'start': 41, 'end': 49, 'concept_id': 'D013577'},
#   {'text': 'Saethre-Chotzen syndrome',
#    'start': 131,
#    'end': 155,
#    'concept_id': 'D000168'},
#   {'text': 'Chotzen syndrome',
#    'start': 139,
#    'end': 155,
#    'concept_id': 'D000168'},
#   {'text': 'syndrome', 'start': 147, 'end': 155, 'concept_id': 'D013577'},
#   {'text': 'autosomal dominant',
#    'start': 166,
#    'end': 184,
#    'concept_id': 'C566739'},
#   {'text': 'craniosynostosis',
#    'start': 198,
#    'end': 214,
#    'concept_id': 'D003398'},
#   {'text': 'was', 'start': 444, 'end': 447, 'concept_id': 'D014923'},
#   {'text': 'Saethre-Chotzen syndrome',
#    'start': 561,
#    'end': 585,
#    'concept_id': 'D000168'},
#   {'text': 'Chotzen syndrome',
#    'start': 569,
#    'end': 585,
#    'concept_id': 'D000168'},
#   {'text': 'syndrome', 'start': 577, 'end': 585, 'concept_id': 'D013577'},
#   {'text': 'synostosis', 'start': 853, 'end': 863, 'concept_id': 'D013580'},
#   {'text': 'brachycephaly', 'start': 865, 'end': 878, 'concept_id': 'D003398'},
#   {'text': 'facial asymmetry',
#    'start': 902,
#    'end': 918,
#    'concept_id': 'D005146'},
#   {'text': 'hypertelorism', 'start': 928, 'end': 941, 'concept_id': 'D006972'},
# ...
#   {'text': 'chronic disease',
#    'start': 999,
#    'end': 1014,
#    'concept_id': 'D002908'},
#   {'text': 'disease', 'start': 1007, 'end': 1014, 'concept_id': 'D004194'},
#   {'text': 'can', 'start': 1019, 'end': 1022, 'concept_id': 'C567382'}],
#  '9869602': [{'text': 'APC', 'start': 25, 'end': 28, 'concept_id': 'D011125'},
#   {'text': 'colorectal cancer',
#    'start': 98,
#    'end': 115,
#    'concept_id': 'D015179'},
#   {'text': 'cancer', 'start': 109, 'end': 115, 'concept_id': 'D009369'},
#   {'text': 'colorectal cancer',
#    'start': 204,
#    'end': 221,
#    'concept_id': 'D015179'},
#   {'text': 'cancer', 'start': 215, 'end': 221, 'concept_id': 'D009369'},
#   {'text': 'APC', 'start': 272, 'end': 275, 'concept_id': 'D011125'},
#   {'text': 'was', 'start': 289, 'end': 292, 'concept_id': 'D014923'},
#   {'text': 'colorectal cancer',
#    'start': 348,
#    'end': 365,
#    'concept_id': 'D015179'},
#   {'text': 'cancer', 'start': 359, 'end': 365, 'concept_id': 'D009369'},
#   {'text': 'colorectal cancer',
#    'start': 484,
#    'end': 501,
#    'concept_id': 'D015179'},
#   {'text': 'cancer', 'start': 495, 'end': 501, 'concept_id': 'D009369'},
#   {'text': 'neoplasia', 'start': 636, 'end': 645, 'concept_id': 'D009369'},
#   {'text': 'colorectal cancer',
#    'start': 777,
#    'end': 794,
#    'concept_id': 'D015179'},
#   {'text': 'cancer', 'start': 788, 'end': 794, 'concept_id': 'D009369'},
#   {'text': 'was', 'start': 803, 'end': 806, 'concept_id': 'D014923'},
#   {'text': 'cancer', 'start': 947, 'end': 953, 'concept_id': 'D009369'},
#   {'text': 'was', 'start': 970, 'end': 973, 'concept_id': 'D014923'},
#   {'text': 'cancer', 'start': 1024, 'end': 1030, 'concept_id': 'D009369'},
#   {'text': 'neoplasia', 'start': 1048, 'end': 1057, 'concept_id': 'D009369'},
#   {'text': 'neoplasia', 'start': 1198, 'end': 1207, 'concept_id': 'D009369'},
#   {'text': 'APC', 'start': 1233, 'end': 1236, 'concept_id': 'D011125'},
#   {'text': 'cancers', 'start': 1307, 'end': 1314, 'concept_id': 'D009369'},
#   {'text': 'colorectal cancer',
#    'start': 1381,
#    'end': 1398,
#    'concept_id': 'D015179'},
#   {'text': 'cancer', 'start': 1392, 'end': 1398, 'concept_id': 'D009369'}],
#  '9888388': [{'text': 'hereditary coproporphyria',
#    'start': 66,
#    'end': 91,
#    'concept_id': 'D046349'},
#   {'text': 'coproporphyria', 'start': 77, 'end': 91, 'concept_id': 'C535469'},
#   {'text': 'Hereditary coproporphyria',
#    'start': 113,
#    'end': 138,
#    'concept_id': 'D046349'},
#   {'text': 'coproporphyria',
#    'start': 124,
#    'end': 138,
#    'concept_id': 'C535469'},
#   {'text': 'hepatic porphyria',
#    'start': 156,
#    'end': 173,
#    'concept_id': 'D017094'},
#   {'text': 'porphyria', 'start': 164, 'end': 173, 'concept_id': 'D011164'},
#   {'text': 'autosomal dominant',
#    'start': 179,
#    'end': 197,
#    'concept_id': 'C566739'},
#   {'text': 'disease', 'start': 311, 'end': 318, 'concept_id': 'D004194'},
#   {'text': 'infectious diseases',
#    'start': 450,
#    'end': 469,
#    'concept_id': 'D003141'},
#   {'text': 'diseases', 'start': 461, 'end': 469, 'concept_id': 'D004194'},
#   {'text': 'diseases', 'start': 461, 'end': 469, 'concept_id': 'C'},
#   {'text': 'photosensitivity',
#    'start': 476,
#    'end': 492,
#    'concept_id': '132100'}],
#  '9888390': [{'text': 'metachromatic leukodystrophy',
#    'start': 92,
#    'end': 120,
#    'concept_id': 'D007966'},
#   {'text': 'metachromatic leukodystrophy',
#    'start': 239,
#    'end': 267,
#    'concept_id': 'D007966'},
#   {'text': 'MLD', 'start': 269, 'end': 272, 'concept_id': 'D007966'},
#   {'text': 'MLD', 'start': 572, 'end': 575, 'concept_id': 'D007966'},
#   {'text': 'was', 'start': 1227, 'end': 1230, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 1259, 'end': 1262, 'concept_id': 'D014923'},
#   {'text': 'MLD', 'start': 1289, 'end': 1292, 'concept_id': 'D007966'},
#   {'text': 'MLD', 'start': 1440, 'end': 1443, 'concept_id': 'D007966'},
#   {'text': 'MLD', 'start': 1557, 'end': 1560, 'concept_id': 'D007966'},
#   {'text': 'disease', 'start': 1620, 'end': 1627, 'concept_id': 'D004194'},
#   {'text': 'disease', 'start': 1880, 'end': 1887, 'concept_id': 'D004194'}],
#  '9927033': [{'text': 'hematological malignancy',
#    'start': 37,
#    'end': 61,
#    'concept_id': 'D019337'},
#   {'text': 'malignancy', 'start': 51, 'end': 61, 'concept_id': 'D009369'},
#   {'text': 'neurofibromatosis',
#    'start': 66,
#    'end': 83,
#    'concept_id': 'D017253'},
#   {'text': 'neurofibromatosis type 1',
#    'start': 66,
#    'end': 90,
#    'concept_id': 'D009456'},
#   {'text': 'hereditary nonpolyposis colorectal cancer',
#    'start': 166,
#    'end': 207,
#    'concept_id': 'D003123'},
#   {'text': 'colorectal cancer',
#    'start': 190,
#    'end': 207,
#    'concept_id': 'D015179'},
#   {'text': 'cancer', 'start': 201, 'end': 207, 'concept_id': 'D009369'},
#   {'text': 'disease', 'start': 213, 'end': 220, 'concept_id': 'D004194'},
#   {'text': 'disease susceptibility',
#    'start': 213,
#    'end': 235,
#    'concept_id': 'D004198'},
#   {'text': 'hereditary nonpolyposis colorectal cancer',
#    'start': 352,
#    'end': 393,
#    'concept_id': 'D003123'},
#   {'text': 'colorectal cancer',
#    'start': 376,
#    'end': 393,
#    'concept_id': 'D015179'},
#   {'text': 'cancer', 'start': 387, 'end': 393, 'concept_id': 'D009369'},
#   {'text': 'hematological malignancy',
#    'start': 415,
#    'end': 439,
#    'concept_id': 'D019337'},
#   {'text': 'malignancy', 'start': 429, 'end': 439, 'concept_id': 'D009369'},
#   {'text': 'neurofibromatosis',
#    'start': 505,
#    'end': 522,
#    'concept_id': 'D017253'},
#   {'text': 'neurofibromatosis type 1',
#    'start': 505,
#    'end': 529,
#    'concept_id': 'D009456'},
#   {'text': 'NF1', 'start': 531, 'end': 534, 'concept_id': 'D009456'},
#   {'text': 'mismatch repair deficiency',
#    'start': 727,
#    'end': 753,
#    'concept_id': 'C536928'},
#   {'text': 'leukemia', 'start': 802, 'end': 810, 'concept_id': 'D007938'},
#   {'text': 'lymphoma', 'start': 818, 'end': 826, 'concept_id': 'D008223'},
#   {'text': 'neurofibromatosis',
#    'start': 843,
#    'end': 860,
#    'concept_id': 'D017253'},
#   {'text': 'neurofibromatosis type 1',
#    'start': 843,
#    'end': 867,
#    'concept_id': 'D009456'}],
#  '9931324': [{'text': 'aniridia',
#    'start': 175,
#    'end': 183,
#    'concept_id': 'D015783'},
#   {'text': 'aniridia', 'start': 293, 'end': 301, 'concept_id': 'D015783'},
#   {'text': 'all', 'start': 341, 'end': 344, 'concept_id': 'D054198'},
#   {'text': 'aniridia', 'start': 742, 'end': 750, 'concept_id': 'D015783'},
#   {'text': 'aniridia', 'start': 976, 'end': 984, 'concept_id': 'D015783'},
#   {'text': 'ectopia pupillae',
#    'start': 1083,
#    'end': 1099,
#    'concept_id': 'C536185'},
#   {'text': 'congenital nystagmus',
#    'start': 1123,
#    'end': 1143,
#    'concept_id': 'D020417'},
#   {'text': 'aniridia', 'start': 1208, 'end': 1216, 'concept_id': 'D015783'},
#   {'text': 'all', 'start': 1241, 'end': 1244, 'concept_id': 'D054198'},
#   {'text': 'all', 'start': 1355, 'end': 1358, 'concept_id': 'D054198'},
#   {'text': 'disease', 'start': 1563, 'end': 1570, 'concept_id': 'D004194'}],
#  '993342': [{'text': 'was', 'start': 311, 'end': 314, 'concept_id': 'D014923'},
#   {'text': 'C2 deficiency', 'start': 453, 'end': 466, 'concept_id': '217000'},
#   {'text': 'C2 deficiency', 'start': 512, 'end': 525, 'concept_id': '217000'},
#   {'text': 'C2 deficiency', 'start': 603, 'end': 616, 'concept_id': '217000'},
#   {'text': 'was', 'start': 699, 'end': 702, 'concept_id': 'D014923'},
#   {'text': 'C2 deficiency', 'start': 734, 'end': 747, 'concept_id': '217000'},
#   {'text': 'was', 'start': 1079, 'end': 1082, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 1174, 'end': 1177, 'concept_id': 'D014923'},
#   {'text': 'C2 deficiency',
#    'start': 1337,
#    'end': 1350,
#    'concept_id': '217000'},
#   {'text': 'C2 deficiency',
#    'start': 1448,
#    'end': 1461,
#    'concept_id': '217000'},
#   {'text': 'C2 deficiency',
#    'start': 1489,
#    'end': 1502,
#    'concept_id': '217000'},
#   {'text': 'C2 deficiency',
#    'start': 1666,
#    'end': 1679,
#    'concept_id': '217000'}],
#  '9949197': [{'text': 'Emery-Dreifuss muscular dystrophy',
#    'start': 68,
#    'end': 101,
#    'concept_id': 'D020389'},
#   {'text': 'muscular dystrophy',
#    'start': 83,
#    'end': 101,
#    'concept_id': 'D009136'},
#   {'text': 'Emery-Dreifuss muscular dystrophy',
#    'start': 173,
#    'end': 206,
#    'concept_id': 'D020389'},
#   {'text': 'muscular dystrophy',
#    'start': 188,
#    'end': 206,
#    'concept_id': 'D009136'},
#   {'text': 'LAP', 'start': 289, 'end': 292, 'concept_id': 'C562861'},
#   {'text': 'LAP', 'start': 295, 'end': 298, 'concept_id': 'C562861'},
#   {'text': 'was', 'start': 1243, 'end': 1246, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 1301, 'end': 1304, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 1382, 'end': 1385, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 1484, 'end': 1487, 'concept_id': 'D014923'}],
#  '9949209': [{'text': 'Wilson disease',
#    'start': 346,
#    'end': 360,
#    'concept_id': 'D006527'},
#   {'text': 'disease', 'start': 353, 'end': 360, 'concept_id': 'D004194'},
#   {'text': 'disease', 'start': 515, 'end': 522, 'concept_id': 'D004194'},
#   {'text': 'Indian childhood cirrhosis',
#    'start': 527,
#    'end': 553,
#    'concept_id': 'C562580'},
#   {'text': 'cirrhosis', 'start': 544, 'end': 553, 'concept_id': 'D005355'},
#   {'text': 'liver disease', 'start': 738, 'end': 751, 'concept_id': 'D008107'},
#   {'text': 'disease', 'start': 744, 'end': 751, 'concept_id': 'D004194'},
#   {'text': 'was', 'start': 791, 'end': 794, 'concept_id': 'D014923'},
#   {'text': 'was', 'start': 1399, 'end': 1402, 'concept_id': 'D014923'}],
#  '9950360': [{'text': 'APC', 'start': 26, 'end': 29, 'concept_id': 'D011125'},
#   {'text': 'FAP', 'start': 96, 'end': 99, 'concept_id': 'C567782'},
#   {'text': 'APC', 'start': 129, 'end': 132, 'concept_id': 'D011125'},
#   {'text': 'colorectal cancer',
#    'start': 155,
#    'end': 172,
#    'concept_id': 'D015179'},
#   {'text': 'cancer', 'start': 166, 'end': 172, 'concept_id': 'D009369'},
#   {'text': 'colorectal cancer',
#    'start': 225,
#    'end': 242,
#    'concept_id': 'D015179'},
#   {'text': 'cancer', 'start': 236, 'end': 242, 'concept_id': 'D009369'},
#   {'text': 'familial adenomatous polyposis',
#    'start': 298,
#    'end': 328,
#    'concept_id': 'D011125'},
#   {'text': 'FAP', 'start': 330, 'end': 333, 'concept_id': 'C567782'},
#   {'text': 'adenomatous polyposis coli',
#    'start': 380,
#    'end': 406,
#    'concept_id': 'D011125'},
#   {'text': 'polyposis coli',
#    'start': 392,
#    'end': 406,
#    'concept_id': 'D011125'},
#   {'text': 'APC', 'start': 408, 'end': 411, 'concept_id': 'D011125'},
#   {'text': 'APC', 'start': 476, 'end': 479, 'concept_id': 'D011125'},
#   {'text': 'was', 'start': 485, 'end': 488, 'concept_id': 'D014923'},
#   {'text': 'APC', 'start': 617, 'end': 620, 'concept_id': 'D011125'},
#   {'text': 'FAP', 'start': 638, 'end': 641, 'concept_id': 'C567782'},
#   {'text': 'colorectal cancer',
#    'start': 642,
#    'end': 659,
#    'concept_id': 'D015179'},
#   {'text': 'cancer', 'start': 653, 'end': 659, 'concept_id': 'D009369'},
#   {'text': 'APC', 'start': 674, 'end': 677, 'concept_id': 'D011125'},
#   {'text': 'was', 'start': 683, 'end': 686, 'concept_id': 'D014923'},
#   {'text': 'FAP', 'start': 713, 'end': 716, 'concept_id': 'C567782'},
#   {'text': 'FAP', 'start': 728, 'end': 731, 'concept_id': 'C567782'},
#   {'text': 'colorectal cancer',
#    'start': 732,
#    'end': 749,
#    'concept_id': 'D015179'},
#   {'text': 'cancer', 'start': 743, 'end': 749, 'concept_id': 'D009369'},
#   {'text': 'FAP', 'start': 943, 'end': 946, 'concept_id': 'C567782'},
#   {'text': 'FAP', 'start': 1056, 'end': 1059, 'concept_id': 'C567782'},
#   {'text': 'colorectal cancer',
#    'start': 1069,
#    'end': 1086,
#    'concept_id': 'D015179'},
#   {'text': 'cancer', 'start': 1080, 'end': 1086, 'concept_id': 'D009369'},
#   {'text': 'FAP', 'start': 1220, 'end': 1223, 'concept_id': 'C567782'},
#   {'text': 'APC', 'start': 1617, 'end': 1620, 'concept_id': 'D011125'},
#   {'text': 'FAP', 'start': 1642, 'end': 1645, 'concept_id': 'C567782'},
#   {'text': 'FAP', 'start': 1654, 'end': 1657, 'concept_id': 'C567782'},
#   {'text': 'colorectal cancer',
#    'start': 1658,
#    'end': 1675,
#    'concept_id': 'D015179'},
#   {'text': 'cancer', 'start': 1669, 'end': 1675, 'concept_id': 'D009369'}],
#  '9973276': [{'text': 'cancer',
#    'start': 35,
#    'end': 41,
#    'concept_id': 'D009369'},
#   {'text': 'APC', 'start': 54, 'end': 57, 'concept_id': 'D011125'},
#   {'text': 'APC', 'start': 129, 'end': 132, 'concept_id': 'D011125'},
#   {'text': 'colorectal tumor',
#    'start': 162,
#    'end': 178,
#    'concept_id': 'D015179'},
#   {'text': 'tumor', 'start': 173, 'end': 178, 'concept_id': 'D009369'},
#   {'text': 'familial adenomatous polyposis',
#    'start': 192,
#    'end': 222,
#    'concept_id': 'D011125'},
#   {'text': 'syndrome', 'start': 223, 'end': 231, 'concept_id': 'D013577'},
#   {'text': 'carcinogenesis',
#    'start': 256,
#    'end': 270,
#    'concept_id': 'D063646'},
#   {'text': 'APC', 'start': 364, 'end': 367, 'concept_id': 'D011125'},
#   {'text': 'APC', 'start': 473, 'end': 476, 'concept_id': 'D011125'},
#   {'text': 'carcinogenesis',
#    'start': 507,
#    'end': 521,
#    'concept_id': 'D063646'},
#   {'text': 'adenomatous polyps',
#    'start': 600,
#    'end': 618,
#    'concept_id': 'D018256'},
#   {'text': 'polyps', 'start': 612, 'end': 618, 'concept_id': 'D011127'},
#   {'text': 'colorectal cancer',
#    'start': 627,
#    'end': 644,
#    'concept_id': 'D015179'},
#   {'text': 'cancer', 'start': 638, 'end': 644, 'concept_id': 'D009369'},
#   {'text': 'APC', 'start': 654, 'end': 657, 'concept_id': 'D011125'},
#   {'text': 'APC', 'start': 683, 'end': 686, 'concept_id': 'D011125'},
#   {'text': 'was', 'start': 701, 'end': 704, 'concept_id': 'D014923'},
#   {'text': 'APC', 'start': 823, 'end': 826, 'concept_id': 'D011125'},
#   {'text': 'neoplasia', 'start': 915, 'end': 924, 'concept_id': 'D009369'},
#   {'text': 'APC', 'start': 981, 'end': 984, 'concept_id': 'D011125'},
#   {'text': 'adenomas', 'start': 1026, 'end': 1034, 'concept_id': 'D000236'},
#   {'text': 'colorectal cancers',
#    'start': 1039,
#    'end': 1057,
#    'concept_id': 'D015179'},
#   {'text': 'cancers', 'start': 1050, 'end': 1057, 'concept_id': 'D009369'},
#   {'text': 'APC', 'start': 1141, 'end': 1144, 'concept_id': 'D011125'},
#   {'text': 'adenoma', 'start': 1179, 'end': 1186, 'concept_id': 'D000236'},
#   {'text': 'all', 'start': 1235, 'end': 1238, 'concept_id': 'D054198'},
#   {'text': 'colorectal cancer',
#    'start': 1256,
#    'end': 1273,
#    'concept_id': 'D015179'},
#   {'text': 'cancer', 'start': 1267, 'end': 1273, 'concept_id': 'D009369'},
#   {'text': 'colorectal cancer',
#    'start': 1507,
#    'end': 1524,
#    'concept_id': 'D015179'},
#   {'text': 'cancer', 'start': 1518, 'end': 1524, 'concept_id': 'D009369'}],
#  '9988281': [{'text': 'breast carcinomas',
#    'start': 70,
#    'end': 87,
#    'concept_id': 'D001943'},
#   {'text': 'carcinomas', 'start': 77, 'end': 87, 'concept_id': 'D002277'},
#   {'text': 'ovarian cancer',
#    'start': 174,
#    'end': 188,
#    'concept_id': 'D010051'},
#   {'text': 'cancer', 'start': 182, 'end': 188, 'concept_id': 'D009369'},
#   {'text': 'cancers', 'start': 248, 'end': 255, 'concept_id': 'D009369'},
#   {'text': 'cancers', 'start': 305, 'end': 312, 'concept_id': 'D009369'},
#   {'text': 'ovarian cancers',
#    'start': 461,
#    'end': 476,
#    'concept_id': 'D010051'},
#   {'text': 'cancers', 'start': 469, 'end': 476, 'concept_id': 'D009369'},
#   {'text': 'all', 'start': 940, 'end': 943, 'concept_id': 'D054198'},
#   {'text': 'malignancies',
#    'start': 1003,
#    'end': 1015,
#    'concept_id': 'D009369'},
#   {'text': 'cancers', 'start': 1140, 'end': 1147, 'concept_id': 'D009369'},
#   {'text': 'ductal carcinomas',
#    'start': 1162,
#    'end': 1179,
#    'concept_id': 'D044584'},
#   {'text': 'carcinomas', 'start': 1169, 'end': 1179, 'concept_id': 'D002277'},
#   {'text': 'was', 'start': 1210, 'end': 1213, 'concept_id': 'D014923'},
#   {'text': 'ductal carcinomas',
#    'start': 1269,
#    'end': 1286,
#    'concept_id': 'D044584'},
#   {'text': 'carcinomas', 'start': 1276, 'end': 1286, 'concept_id': 'D002277'},
#   {'text': 'cancers', 'start': 1403, 'end': 1410, 'concept_id': 'D009369'}]}

# %%
output_file = "predictions.tsv"

with open(output_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file, delimiter='\t')  
    
    writer.writerow(["doc_id", "mention", "start", "end", "concept_id"])
    
    for doc_id, annotations in all_predictions.items():
        for annotation in annotations:
            writer.writerow([doc_id, annotation['mention'], annotation['start'], annotation['end'], annotation['concept_id']])

print(f"Predictions have been saved to {output_file}")
# Out:
# Predictions have been saved to predictions.tsv

# %%
pred_df = pd.read_csv("D:/OGER/OGER/predictions.tsv", sep="\t")
gold_df = pd.read_csv("D:/OGER/OGER/data/ncbi_annotations/gold_annotations.tsv", sep="\t")

# %%
def exact_match(pred, gold):
    return (
        pred['doc_id'] == gold['doc_id'] and
        pred['start'] == gold['start'] and
        pred['end'] == gold['end'] 
    )

def partial_match(pred, gold):
    return (
        pred['doc_id'] == gold['doc_id'] and
        not (pred['end'] <= gold['start'] or pred['start'] >= gold['end']) 
    )

# %%
def evaluate(pred_df, gold_df, match_func):
    tp = 0
    matched_gold = set()

    for _, pred_row in pred_df.iterrows():
        match_found = False
        for idx, gold_row in gold_df.iterrows():
            if idx in matched_gold:
                continue
            if match_func(pred_row, gold_row):
                tp += 1
                matched_gold.add(idx)
                match_found = True
                break

    fp = len(pred_df) - tp
    fn = len(gold_df) - tp

    precision = tp / (tp + fp) if tp + fp else 0.0
    recall = tp / (tp + fn) if tp + fn else 0.0
    f1 = 2 * precision * recall / (precision + recall) if precision + recall else 0.0

    return precision, recall, f1, fp, fn, tp

# %%
exact_precision, exact_recall, exact_f1, exact_fp, exact_fn, exact_tp = evaluate(pred_df, gold_df, exact_match)
partial_precision, partial_recall, partial_f1, partial_fp, partial_fn, partial_tp = evaluate(pred_df, gold_df, partial_match)

print(f"Exact Match: P={exact_precision:.6f}, R={exact_recall:.6f}, F1={exact_f1:.6f}, fp={exact_fp:.6f}, fn={exact_fn:.6f}, tp={exact_tp:.6f}")
print(f"Partial Match: P={partial_precision:.6f}, R={partial_recall:.6f}, F1={partial_f1:.6f}, fp={partial_fp:.6f}, fn={partial_fn:.6f}, tp={partial_tp:.6f}")
# Out:
# Exact Match: P=0.359582, R=0.537500, F1=0.430898, fp=919.000000, fn=444.000000, tp=516.000000
# Partial Match: P=0.464111, R=0.693750, F1=0.556159, fp=769.000000, fn=294.000000, tp=666.000000

# %% [markdown]
# Applying OGER using command line:

# %%
# !python -m oger run --settings D:/OGER/settings.ini -c termlist0-normalize "[\"lowercase\"]"
# Out:
# Recognizers configuration: (<oger.ctrl.parameters.ERParams object at 0x000002584FA0CA60>,)
# Initializing EntityRecognizer with config: <oger.ctrl.parameters.ERParams object at 0x000002584FA0CA60>

# %%
#lenient
# !python -m oger eval -t tsv -g D:/OGER/OGER/data/ncbi_annotations/gold_annotations.tsv -a D:/OGER/OGER/output/combined_output.tsv -G 1,2,3 -A 1,3,4 -k 1 -o 3,4 --lenient -p -r -f -c
# Out:
# Precision	0.5292517006802722
# Recall	0.809573361082206
# F1	0.6400658165364048
# TP	622
# FP	692
# FN	183
# PP	156

# %%
#exact
# !python -m oger eval -t tsv -g D:/OGER/OGER/data/ncbi_annotations/gold_annotations.tsv -a D:/OGER/OGER/output/combined_output.tsv -G 1,2,3 -A 1,3,4 -k 1 -o 3,4 --strict -p -r -f -c
# Out:
# Precision	0.4231292517006803
# Recall	0.6472424557752341
# F1	0.5117235705470998
# TP	622
# FP	848
# FN	339
